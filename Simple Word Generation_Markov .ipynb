# %%
import numpy as np
trump = open('speeches.txt',encoding='utf-8').read()

# %%
corpus = trump.split()

# %%
def make_pairs(corpus):
    for i in range(len(corpus)-1):
        yield(corpus[i],corpus[i+1])

# %%
pairs = make_pairs(corpus)

# %%
word_dict = {}
for word_1, word_2 in pairs:
    if word_1 in word_dict.keys():
        word_dict[word_1].append(word_2)
    else:
        word_dict[word_1] = [word_2]
    
first_word = np.random.choice(corpus)

# %%
word_dict
# Out:
# {'\ufeffSPEECH': ['1'],
#  '1': ['...Thank', 'one', 'percent,', 'million'],
#  '...Thank': ['you', 'you.'],
#  'you': ['so',
#   "I'm",
#   'want',
#   'think',
#   'have',
#   'will',
#   'will',
#   'did',
#   'were',
#   'would',
#   'would',
#   'have',
#   'know',
#   'and',
#   'could',
#   'sell',
#   'to',
#   'to',
#   'watch',
#   'hear',
#   'out;',
#   'know',
#   'that',
#   'deserve',
#   'know',
#   'can',
#   'can',
#   'let',
#   'take',
#   'can',
#   'can',
#   'very',
#   'have',
#   'have',
#   'have',
#   'have',
#   'look',
#   'look',
#   'look',
#   'look',
#   'an',
#   'ever',
#   'know--',
#   'think',
#   'something.',
#   "can't",
#   'got',
#   "can't",
#   'know',
#   'have',
#   'believe',
#   'all',
#   'very',
#   'for',
#   'to',
#   'must',
#   'just',
#   'will',
#   'have',
#   'have',
#   'remember',
#   'name',
#   'will',
#   'know',
#   'have',
#   'take',
#   'do,',
#   'very',
#   'know',
#   'know',
#   'have',
#   'mean?"',
#   'were',
#   'had',
#   'know',
#   'have',
#   'very',
#   'know',
#   'listen',
#   'know,',
#   'could',
#   'know',
#   'were',
#   'what',
#   'folks,',
#   'should',
#   'it',
#   'pastor',
#   'know',
#   'know',
#   'know',
#   'know',
#   'just',
#   'Mexico',
#   'folks',
#   'very',
#   'very',
#   'saw',
#   'believe',
#   'this,',
#   'that',
#   'need',
#   'running?',
#   'not',
#   'heard',
#   'wouldn’t',
#   'don’t',
#   'what,',
#   'can’t',
#   'know',
#   'need',
#   'that.',
#   '—',
#   'a',
#   'need',
#   'don’t',
#   'don’t',
#   'don’t',
#   'have',
#   'know,',
#   'this',
#   'tariff',
#   'don’t',
#   'go',
#   'never',
#   'know,',
#   'say',
#   'the',
#   'a',
#   'know,',
#   'can’t',
#   'need',
#   'another',
#   'look',
#   'really',
#   'looked',
#   'get',
#   'know',
#   'run,',
#   'have',
#   '—',
#   'know,',
#   'don’t',
#   '$4',
#   'know',
#   'about',
#   'know,',
#   'vote',
#   'have',
#   'very',
#   'know,',
#   'know',
#   'know,',
#   'see',
#   'see',
#   'would’ve',
#   'what,',
#   'look',
#   'look',
#   'look',
#   'with',
#   'want,',
#   'before',
#   'want',
#   'go',
#   'look',
#   'know,',
#   'look',
#   'see',
#   'this.',
#   'can',
#   'have',
#   'have',
#   'one',
#   'know,',
#   'can',
#   'want,',
#   'know,',
#   '—',
#   'know,',
#   'supposed',
#   'look',
#   'look',
#   'know,',
#   'can’t',
#   'know,',
#   'have',
#   'can’t',
#   'have',
#   'we',
#   'saw',
#   'should',
#   'folks',
#   'don’t',
#   'think',
#   'want',
#   'go,',
#   'wouldn’t',
#   'look',
#   'go',
#   'take',
#   'take',
#   'say',
#   '—',
#   'know',
#   'see',
#   'know,',
#   'know,',
#   'can',
#   'can',
#   'know,',
#   'go',
#   'go',
#   'go',
#   'go',
#   'look',
#   'will',
#   'take',
#   'look',
#   'that.',
#   'that',
#   'know,',
#   'look',
#   'had',
#   'know,',
#   'with',
#   'very',
#   'very',
#   'know,',
#   'like',
#   'know,',
#   'know,',
#   'believe',
#   'know,',
#   'around.',
#   'what,',
#   'know,',
#   'know?',
#   'know,',
#   'know,',
#   'know,',
#   'too,',
#   'know',
#   'do',
#   'would',
#   'have',
#   'believe',
#   'know.',
#   'know,',
#   'know,',
#   'can’t',
#   'don’t',
#   'have',
#   'noticed',
#   'know,',
#   'say,',
#   'look?',
#   'know,',
#   'know,',
#   'this?"',
#   'are',
#   'were',
#   'were',
#   'are',
#   'see',
#   'know,',
#   'don’t',
#   'going',
#   'say',
#   'saw',
#   'know,',
#   'see',
#   'believe',
#   'know',
#   'who',
#   'who',
#   'just',
#   'know',
#   'have',
#   'can’t',
#   'around.',
#   'look',
#   'know,',
#   'know,',
#   'much',
#   'are',
#   'will',
#   'are',
#   'will',
#   'imagine',
#   'want',
#   'have',
#   'a',
#   'on',
#   'know,',
#   'know.',
#   'know,',
#   'know,',
#   'on',
#   'know.',
#   'go',
#   'know,',
#   'remember',
#   'have',
#   'do',
#   'believe',
#   'had',
#   'don’t',
#   'that',
#   'know,',
#   'almost',
#   'said,',
#   'know,',
#   'ever',
#   'know?',
#   'know,',
#   'don’t',
#   'what,',
#   'look',
#   'know,',
#   'know,',
#   'hear',
#   'had',
#   'had',
#   'go',
#   'announce',
#   'are',
#   'know,',
#   'know,',
#   '—',
#   'say',
#   'know,',
#   'talk',
#   'wouldn’t',
#   'know,',
#   'don’t',
#   'have',
#   'know',
#   'know,',
#   'going',
#   'ever',
#   'see',
#   'talk',
#   'what,',
#   'believe',
#   'have',
#   'say',
#   'know,',
#   'are',
#   '(ph).',
#   'applaud,',
#   'finish',
#   'know',
#   'like',
#   'talk',
#   'and',
#   'believe',
#   'going',
#   'know,',
#   'hear',
#   'know,',
#   'people.',
#   'are',
#   'can’t',
#   'have',
#   'believe',
#   'know,',
#   'don’t',
#   'should',
#   'get',
#   'know,',
#   'hear',
#   'know,',
#   'say."',
#   'know,',
#   'have',
#   'won’t',
#   'won’t',
#   'why.',
#   'the',
#   'agree?',
#   'understand',
#   'understand',
#   'had',
#   'get',
#   'know',
#   'think',
#   'as',
#   'don’t',
#   'know',
#   'go',
#   'to',
#   'have',
#   'don’t,',
#   'know,',
#   'have',
#   'this.',
#   'very',
#   'and',
#   'doing?"',
#   'to',
#   'know',
#   'and',
#   'so',
#   'for',
#   '...',
#   'very',
#   'very',
#   'add',
#   'win',
#   'have',
#   'look',
#   'have',
#   'have',
#   'say',
#   'go',
#   'go',
#   'say.',
#   'add',
#   '(pointing',
#   '(pointing',
#   'what:',
#   'know',
#   'have',
#   'imagine',
#   'like',
#   'don’t',
#   'who',
#   'right',
#   'wonder',
#   'wonder',
#   'know',
#   'know',
#   'just',
#   'very',
#   'very',
#   'very',
#   'very',
#   'today',
#   'about',
#   'about',
#   'know,',
#   'what,',
#   'want',
#   'talk',
#   'know,',
#   'know',
#   'know',
#   'make',
#   'treat',
#   'need',
#   'have',
#   'live',
#   'live',
#   'see',
#   'have',
#   'very',
#   'everybody.',
#   'very',
#   'very',
#   'know',
#   'down',
#   'down.',
#   'proud',
#   'very,',
#   'with',
#   'see',
#   'could’ve',
#   'all',
#   'mean',
#   'are,',
#   'our',
#   'that',
#   'and',
#   'very',
#   'for',
#   'imagine',
#   'know,',
#   'folks.',
#   'ever',
#   'know',
#   'know,',
#   'have',
#   'the',
#   'can’t',
#   'want',
#   'press',
#   'have',
#   '15',
#   'wouldn’t',
#   'have',
#   'know',
#   'do',
#   'know,',
#   'probably',
#   'what.',
#   'all',
#   'know,',
#   'people.',
#   'know',
#   'sure',
#   'have',
#   'in',
#   'know',
#   'know.',
#   'get',
#   'have',
#   'imagine,',
#   'don’t',
#   'know,',
#   'go',
#   'say',
#   'know,',
#   'hear?',
#   'know,',
#   'know',
#   'have',
#   'know',
#   'know,',
#   'know".',
#   'watch',
#   'think',
#   'see',
#   'could',
#   'anymore."',
#   'don’t',
#   'to',
#   'kidding',
#   'have',
#   'know.',
#   'look',
#   'see',
#   'don’t',
#   'do',
#   'can',
#   'can',
#   'can',
#   'think',
#   'know',
#   'know',
#   'could',
#   'had',
#   'have',
#   'had',
#   'have',
#   'know,',
#   'have',
#   'think',
#   'always',
#   'ever',
#   'other',
#   'know,',
#   'believe',
#   'give',
#   'have',
#   'have',
#   'have',
#   'give',
#   'really',
#   'think',
#   'know,',
#   'know,',
#   'run,',
#   'actually',
#   'can’t',
#   'on',
#   'on',
#   'doing',
#   'know,',
#   'know',
#   'tonight.',
#   'don’t',
#   'know,',
#   'know,',
#   'one',
#   'how',
#   '100%...We',
#   '100%.',
#   'in',
#   'know',
#   'believe',
#   'see',
#   'know,',
#   'how',
#   'know,',
#   'get',
#   'go',
#   'very',
#   'know',
#   'down.',
#   'down.',
#   'proud',
#   'very,',
#   'with',
#   '–',
#   'see,',
#   'could',
#   'all',
#   'mean',
#   'are,',
#   'that',
#   'and',
#   'very',
#   'very',
#   'know,',
#   'think',
#   'look',
#   'know.',
#   'asked',
#   'I',
#   'in',
#   'have',
#   'the',
#   'want.',
#   'very',
#   'make',
#   'want.',
#   'ready?',
#   'have',
#   'have',
#   'send',
#   'the',
#   'ready?',
#   'have',
#   'know',
#   'that',
#   'go',
#   'have',
#   'can',
#   '–',
#   'found',
#   'understand.',
#   'the',
#   'look',
#   'understand.',
#   'know,',
#   'pay',
#   'could',
#   'know',
#   'on',
#   'or',
#   'that',
#   'understand.',
#   'that.',
#   'another',
#   'could',
#   'weren’t',
#   'to',
#   'could',
#   'know',
#   'know',
#   'look',
#   'know',
#   'a',
#   'raise',
#   'know,',
#   'can',
#   'know,',
#   'they',
#   'look',
#   'look',
#   'people',
#   'settle',
#   'know',
#   'know',
#   'say',
#   'signed',
#   'signed',
#   'can’t',
#   'can’t',
#   'will',
#   'will',
#   'put',
#   '–',
#   'guys',
#   'lose',
#   'lose',
#   'will',
#   'why...He',
#   'know.',
#   'think',
#   'know',
#   'would',
#   'know',
#   'read',
#   'understand.',
#   'read',
#   'think',
#   'want',
#   'do',
#   'something.',
#   'were',
#   'understand',
#   'all',
#   'very',
#   'very',
#   'know',
#   'folks,',
#   'what.',
#   'have',
#   'know,',
#   'that',
#   'that',
#   'understand',
#   'what,',
#   'that',
#   'know,',
#   'go',
#   'see',
#   'know,',
#   'folks',
#   'know',
#   'wouldn’t',
#   'and',
#   'said',
#   'possibly',
#   'all.',
#   'very',
#   'very',
#   'mind?',
#   'mind',
#   'to',
#   'to',
#   'very',
#   'didn’t',
#   'know,',
#   'so',
#   'know',
#   'know',
#   'can',
#   'that’s',
#   'noticed',
#   'up"',
#   'all',
#   'get',
#   'do',
#   'do',
#   'say,',
#   'do',
#   'do',
#   'do',
#   'get',
#   'want,',
#   'could',
#   'say',
#   'go',
#   'run.',
#   'what,',
#   'know',
#   'know,',
#   'know',
#   'know,',
#   'see',
#   'imagine',
#   'think?',
#   'see',
#   'think?',
#   'knock',
#   'know,',
#   'think?',
#   'have',
#   'have',
#   'people.',
#   'want,',
#   'can.',
#   'possibly',
#   'something,',
#   'have',
#   'have',
#   'going',
#   'understand',
#   'want',
#   'want',
#   'ready',
#   'have',
#   'haven’t.',
#   'in,',
#   'in',
#   'might',
#   'bit',
#   'took',
#   'want',
#   'look',
#   'see',
#   'know,',
#   'a',
#   'want',
#   'see',
#   'but',
#   'see',
#   'can',
#   'stop',
#   'for',
#   'need',
#   'have',
#   'can’t',
#   'money.',
#   'know',
#   'ever',
#   'know,',
#   'noticed',
#   'ever',
#   'know,',
#   'know',
#   'have',
#   'need',
#   'don’t',
#   'have',
#   'have',
#   'going',
#   'know,',
#   'know,',
#   'know,',
#   'that',
#   'about',
#   'know',
#   'have',
#   'associate',
#   'know',
#   'can’t',
#   'have',
#   'know',
#   'know,',
#   'know,',
#   'talk',
#   'talk',
#   'can',
#   'do',
#   'know',
#   'want',
#   'get',
#   'know',
#   'listen',
#   'imagine?',
#   'ever',
#   'that.',
#   'know,',
#   'always',
#   'and',
#   'think',
#   'one',
#   'can',
#   'don’t',
#   'know,',
#   'added',
#   'add',
#   'think',
#   'know,',
#   'need',
#   'look',
#   'know,',
#   'know',
#   'imagine?',
#   'believe',
#   'win,',
#   'lose,',
#   'know,',
#   'look',
#   'look',
#   'look',
#   'look',
#   'too.',
#   'to',
#   'get',
#   'can',
#   'very',
#   'all!',
#   'very',
#   'know,',
#   'something',
#   'know,',
#   'understand,',
#   'free.',
#   'free.',
#   'too.',
#   'know,',
#   'saw',
#   'know',
#   'know,',
#   'have',
#   'know,',
#   'were',
#   'have',
#   'convinced',
#   'get',
#   'have',
#   'crack',
#   'have',
#   'one',
#   'can’t',
#   'can’t',
#   'have',
#   'millions',
#   'want',
#   'how',
#   'know.',
#   'fight',
#   'know,',
#   'do',
#   'want',
#   'want',
#   'after',
#   'finish.',
#   'know,',
#   'ever',
#   'can’t',
#   'can',
#   'don’t',
#   'don’t',
#   'want',
#   'can’t',
#   'see',
#   'say',
#   'think',
#   'know,',
#   'tell',
#   'know,',
#   'could',
#   'what.',
#   'folks',
#   'allow',
#   'more',
#   'know,',
#   'know,',
#   'know,',
#   'think',
#   'know,',
#   'can',
#   'know',
#   'get',
#   'like',
#   'like',
#   'all',
#   'mostly',
#   'folks',
#   'can',
#   'have',
#   'have',
#   'know,',
#   'know',
#   'think.',
#   'look',
#   'look',
#   'now.',
#   'have',
#   'know',
#   'look',
#   'think',
#   'in',
#   'this.',
#   'have',
#   'will',
#   'how',
#   'know,',
#   'probably',
#   'think?',
#   'think?',
#   'start',
#   'see',
#   'know',
#   'see',
#   'know,',
#   'even',
#   'a',
#   'something,',
#   'right',
#   'about',
#   'know',
#   'what.',
#   'just',
#   'said',
#   'know,',
#   'have',
#   'trust?',
#   'a',
#   'coming',
#   'in',
#   'because',
#   'and',
#   'back',
#   'know',
#   'know,',
#   'because',
#   'have',
#   'can’t',
#   'this',
#   'couldn’t',
#   'ever',
#   'do',
#   'can."',
#   'wouldn’t',
#   'wouldn’t',
#   'wouldn’t',
#   'need',
#   'know,',
#   'have',
#   'just',
#   'have',
#   'all.',
#   'all.',
#   ...],
#  'so': ['much.',
#   'nice.',
#   'complicated',
#   'terrible',
#   'terrible.',
#   'unfair.',
#   'incompetent.',
#   'many',
#   'much;',
#   'many',
#   'many--',
#   'much',
#   'much',
#   'much--goods,',
#   'many',
#   'weak',
#   'many',
#   'many',
#   'we',
#   'we',
#   'that',
#   'that',
#   'you',
#   'many',
#   'many',
#   "I'll",
#   'old',
#   'much',
#   'badly',
#   'simple.',
#   'quick',
#   'when',
#   'much',
#   'nice,',
#   'easy',
#   'much',
#   'many',
#   'much,',
#   'sadly,',
#   'vividly',
#   'many',
#   'much',
#   'important.',
#   'if',
#   'important,',
#   'many',
#   'many',
#   'I’m',
#   'just',
#   'much',
#   'much',
#   'incredible',
#   'much',
#   'proud.',
#   'high,',
#   'many',
#   'rampant.',
#   'many',
#   'I’d',
#   'tough."',
#   'well,',
#   'many',
#   'their',
#   'brilliantly,',
#   'stupid.',
#   'nice',
#   'much',
#   'rich',
#   'nobody',
#   'much.',
#   'much',
#   'bloated.',
#   'important.',
#   'I',
#   'long.',
#   'great',
#   'great',
#   'much',
#   'many',
#   'many',
#   'many',
#   'beautiful',
#   'strongly.',
#   'many',
#   'much',
#   'proud',
#   'many',
#   'much.',
#   'honored',
#   'many',
#   'votes.',
#   'that',
#   'nasty,',
#   'much',
#   'easy.',
#   'beautifully.',
#   'incredible',
#   'bucolic,',
#   'beautiful.',
#   'beautiful.',
#   'many',
#   'many',
#   'energized.',
#   '—',
#   'incredible.',
#   'fed',
#   'much',
#   'beautiful',
#   'fast.',
#   'I',
#   'theatrical;',
#   'many',
#   'nonsense.',
#   'I',
#   'lovely',
#   'bad',
#   'rich',
#   'rich.',
#   'Gadhafi',
#   'much,',
#   'they',
#   'well.',
#   'well.',
#   'we',
#   'that',
#   'much',
#   'much',
#   'big',
#   'fair.',
#   'bad,',
#   'out',
#   'many',
#   'good,',
#   'many',
#   'I',
#   'excited,',
#   'much',
#   'many',
#   'much',
#   'many',
#   'smart.',
#   'many',
#   'funny;',
#   'Ted’s',
#   'many',
#   'proud',
#   'many.',
#   'Chuck,',
#   'good.',
#   'that',
#   'badly',
#   'much.',
#   'easy',
#   'three',
#   'I',
#   'important',
#   'thank',
#   'deeply',
#   'many',
#   'thank',
#   'many',
#   'many',
#   'many',
#   'much',
#   'much',
#   'different.',
#   'big,',
#   'good,',
#   'strong,',
#   'powerful',
#   'many',
#   'many',
#   'incredible',
#   'many',
#   'many',
#   'much',
#   'many',
#   'much',
#   'badly,',
#   'sad',
#   'important.',
#   'but',
#   'they',
#   'when',
#   'stupidly',
#   'preposterous.',
#   'I’m',
#   'it’s',
#   'long',
#   'vehemently',
#   'strongly,',
#   'good',
#   'far',
#   'sad.',
#   'long.',
#   'many',
#   'much',
#   '--',
#   'many',
#   'much',
#   'well',
#   'sick',
#   'much',
#   'great',
#   'much.',
#   'good,',
#   'much',
#   'high',
#   'important.',
#   'important...',
#   'great',
#   'many',
#   '–',
#   'I',
#   'they',
#   'well.',
#   'well.',
#   'important',
#   'incredible.',
#   'incredible.',
#   'I',
#   'it’s',
#   'much',
#   'much.',
#   'it’s',
#   'bad.',
#   '6',
#   'and',
#   'I',
#   'you',
#   'many',
#   'big',
#   'strong',
#   'powerful',
#   'powerful',
#   'it’s',
#   'simple.',
#   'simple.',
#   'than',
#   'we’re',
#   'we',
#   'I’m',
#   'corrupt.',
#   'totally',
#   'horrible.',
#   'and',
#   'gave',
#   'out',
#   'terrible.',
#   'little',
#   'happy',
#   'much',
#   'I',
#   'finally',
#   'many',
#   'we',
#   'wrong.',
#   'many',
#   'important.',
#   'strong',
#   'wonderful.',
#   'sad',
#   'sad.',
#   'many',
#   'vehemently',
#   'strongly',
#   'good',
#   'far',
#   'sad,',
#   'long.',
#   'I',
#   'many',
#   'many',
#   'many',
#   'thankful',
#   'you',
#   'dishonest',
#   'unfair.',
#   'I',
#   'you',
#   'happy.',
#   'badly.',
#   'you',
#   'I’m',
#   'many',
#   'many',
#   'beautiful',
#   'beautiful',
#   'well',
#   'good?',
#   'you',
#   'important',
#   'smart.',
#   'great',
#   'great',
#   'you',
#   'good,',
#   'I',
#   'wrong',
#   'unfair',
#   'incredible',
#   'badly.',
#   'incredible',
#   'many',
#   'much',
#   'many',
#   'many',
#   'good.',
#   'proud',
#   'taken,',
#   'beautifully.',
#   'amazing',
#   'supportive',
#   'like',
#   'sad',
#   'many',
#   'many',
#   'much.',
#   'sick',
#   'much',
#   'inspiring',
#   'many',
#   'easy."',
#   'easy.',
#   'important.',
#   'beautiful,’',
#   'badly.',
#   'vigilant',
#   'politically',
#   'stupidly',
#   'stupid."',
#   'down',
#   'gloomy',
#   'many',
#   'we',
#   'much.',
#   'into',
#   'we',
#   'I',
#   'totally',
#   'smart.',
#   'sharp.',
#   'long?',
#   'we',
#   'badly',
#   'hard,',
#   'diligently',
#   'bad',
#   'unfairly.',
#   'great',
#   'strong.',
#   'many',
#   'proud',
#   'proud',
#   'proud',
#   'badly.',
#   'important.',
#   'special',
#   'amazing',
#   'you',
#   'hard.',
#   'and',
#   'I',
#   'many',
#   'many',
#   'well',
#   'well.',
#   'nice',
#   'nice.',
#   'unfair.',
#   'dishonest.',
#   'you',
#   'dramatic.',
#   'guilty',
#   'guilty.',
#   'low',
#   'you',
#   'great',
#   'strong',
#   'amazing.',
#   'I’m',
#   'quick',
#   'small.',
#   'much',
#   'much',
#   'many',
#   'much',
#   'strong',
#   'great.',
#   'much?"',
#   'important',
#   'stupid?"',
#   'stupid',
#   'much.',
#   'bad?',
#   'quickly.',
#   'many',
#   'good',
#   'I',
#   'easy.',
#   'smart.',
#   'smart.',
#   'they',
#   'happy.',
#   'great',
#   'many',
#   'wrong.',
#   'nice.',
#   'much',
#   'false.',
#   'I',
#   'I',
#   'amazing.',
#   'incredible,',
#   'hard.',
#   'I',
#   'helpful',
#   'we’re',
#   'many',
#   'distant',
#   'many',
#   'many',
#   'incredible.',
#   'many',
#   'supportive',
#   'supportive.',
#   'badly?',
#   'badly.',
#   'good',
#   'good',
#   'important.',
#   'important',
#   'fast.',
#   'fast',
#   'high.',
#   'amazing.',
#   '...',
#   'high,',
#   'much',
#   'much',
#   'much',
#   'big,',
#   'strong,',
#   'powerful,',
#   'massive.',
#   'smart,',
#   'much.',
#   'incredible',
#   'we',
#   'much',
#   'much',
#   'happy',
#   'much',
#   'well.',
#   'important.',
#   'and',
#   'has',
#   'I',
#   'you',
#   'maybe',
#   'much',
#   'sick',
#   'fair.',
#   'supportive',
#   'wonderful.',
#   'badly.',
#   'closely.',
#   'we',
#   'cold.',
#   'cold."',
#   'much',
#   'they’re',
#   'badly',
#   'much.',
#   'much',
#   'much',
#   'long.',
#   'honored.',
#   'bad,',
#   'high',
#   'many',
#   'much.',
#   'what',
#   'low.',
#   'many',
#   'important',
#   'important',
#   'strong,',
#   'powerful,',
#   'great,',
#   'great,',
#   'strong',
#   'you',
#   'far',
#   'far',
#   'much',
#   'bad.',
#   'simple',
#   'much',
#   'much',
#   'far,',
#   'many',
#   '–',
#   'dishonest.',
#   'dishonest.',
#   'dishonest.',
#   'somebody',
#   'we',
#   'important.',
#   'many',
#   'friendly',
#   'I',
#   'well',
#   'many',
#   'great.',
#   'much',
#   'far.',
#   'many',
#   'long?',
#   'easy.',
#   'I',
#   'complicated.',
#   'now,',
#   'I',
#   'I',
#   'embarrassed',
#   'many',
#   'embarrassing',
#   'I',
#   'many',
#   'great.',
#   'bad',
#   'defining.',
#   'important,',
#   'happy',
#   'much',
#   'much',
#   'many',
#   'great',
#   'everyone’s',
#   'onerous',
#   'important.',
#   'than',
#   'many',
#   'fast',
#   'well',
#   'successful',
#   'many',
#   'hard',
#   'that',
#   'much',
#   'stupid',
#   'obvious.',
#   'well',
#   'poorly.',
#   'poorly.',
#   'bad.',
#   'important.',
#   'that',
#   'fast.',
#   'much',
#   'corrupt',
#   'successful',
#   'incredible',
#   'financially',
#   'many',
#   'many',
#   'far',
#   'much',
#   'incredible.',
#   'many',
#   'we’re',
#   'you',
#   'nastily,',
#   'far',
#   'big.',
#   'massive',
#   'astronomical',
#   'many',
#   'incredible.',
#   'fast',
#   'many',
#   'complicated.',
#   'much',
#   'bad.',
#   'bad.',
#   'easy',
#   'unfair',
#   'much',
#   'nice',
#   'and',
#   'predictable',
#   'good.',
#   'strong,',
#   'tough,',
#   'incredible,',
#   'badly.',
#   'beautiful.',
#   'damn',
#   'much',
#   'great."',
#   'incredibly',
#   'many',
#   'good',
#   'good.',
#   'power',
#   'much',
#   'many',
#   'they’d',
#   'I’m',
#   'little.',
#   'they',
#   'smart.',
#   'important',
#   'they',
#   'good',
#   'great.',
#   'that’s',
#   'important.',
#   'simple',
#   'well',
#   'crazy.',
#   'fast,',
#   'fast.',
#   'far',
#   'much',
#   'much',
#   'much',
#   'many',
#   'fast',
#   'left',
#   'left',
#   'many',
#   'many',
#   'tough.',
#   'important',
#   'important,',
#   'important.',
#   'low',
#   'complex.',
#   'much',
#   'much',
#   'much',
#   'well',
#   'well',
#   'well',
#   'much',
#   'much',
#   'stupidly',
#   'good',
#   'false.',
#   'well?',
#   'far',
#   'bad',
#   'I',
#   'happy.',
#   'many',
#   'many',
#   'strongly',
#   'well',
#   'big',
#   'strong',
#   'great.',
#   'powerful',
#   'happy',
#   'many',
#   'great.',
#   'strong.',
#   'strongly',
#   'thrilled',
#   'happy.',
#   'many',
#   'far',
#   'much',
#   'intent',
#   'nice',
#   'great.',
#   'we',
#   'that',
#   'famous.',
#   'famous.',
#   'great',
#   'strong',
#   'badly.',
#   'badly.',
#   'badly',
#   'many',
#   'important',
#   'many',
#   'many',
#   'many',
#   'many',
#   'nice.',
#   'two',
#   'many',
#   'I',
#   'high.',
#   'well',
#   'bad',
#   'I',
#   'bad?',
#   'bad?"',
#   'bad?',
#   'incredible.',
#   'many',
#   'much.',
#   'intertwined',
#   'much',
#   'proud.',
#   'good.',
#   'good.',
#   'good.',
#   'here',
#   'angry',
#   'beautiful.',
#   'important',
#   'incredible.',
#   'happy',
#   'easy.',
#   'you',
#   'much',
#   'many',
#   'successful.',
#   'well.',
#   'fast.',
#   'fast',
#   'strong.',
#   'powerful',
#   'strong',
#   'strong.',
#   'nice',
#   'angrily',
#   'proud',
#   'many',
#   'special.',
#   'many',
#   'badly,',
#   'many',
#   "that's",
#   'amazing.',
#   'proud',
#   'proud',
#   'many',
#   'many',
#   'powerful',
#   'that',
#   'that',
#   'out',
#   'much',
#   'much'],
#  'much.': ["That's",
#   'Thank',
#   'Great',
#   'Remember:',
#   'That’s',
#   'He',
#   'I',
#   'No',
#   'We',
#   'But',
#   'Thank',
#   'OK?',
#   'Thank',
#   'So',
#   'But',
#   'Thank',
#   'Thank',
#   'I',
#   'This',
#   'Wow.',
#   'Hello.',
#   'To',
#   'We',
#   'So',
#   'I',
#   'Hello.',
#   'To',
#   'We',
#   'This',
#   'But',
#   'Thank',
#   'Well,',
#   'And',
#   'Thank',
#   'I',
#   'So,',
#   'And',
#   'Do',
#   'Look,',
#   'Thank',
#   'You’re',
#   'And',
#   'And',
#   'Thank',
#   'But',
#   'South',
#   'It’s',
#   'You’ve',
#   'I',
#   'But',
#   'Just',
#   'I',
#   'Most',
#   'I',
#   'It’s',
#   'Thank',
#   'And',
#   'I',
#   'And',
#   'Thank',
#   'Not',
#   "That's",
#   'I'],
#  "That's": ['so',
#   'like',
#   'it.',
#   'it.',
#   'not',
#   'the',
#   'it.',
#   'more',
#   'more',
#   'more',
#   'where',
#   'all',
#   'the',
#   'like',
#   'as',
#   'a',
#   'a'],
#  'nice.': ["Isn't",
#   'They',
#   'Thank',
#   'I',
#   'Thank',
#   'And',
#   'I',
#   'And',
#   'So',
#   'I’ve',
#   'I',
#   'But',
#   'Thank',
#   'They',
#   'Some',
#   'Some',
#   'They’re',
#   'And',
#   'He’s',
#   'I’m',
#   'Even',
#   'But',
#   'So',
#   'But',
#   'Everything’s',
#   'Except',
#   'But'],
#  "Isn't": ['he', 'that', 'that'],
#  'he': ['a',
#   "doesn't",
#   'has',
#   'needs',
#   'was',
#   'lied',
#   'do?',
#   'said,',
#   'made,',
#   'choked.',
#   'runs,',
#   'appointed',
#   'is',
#   'said,',
#   'did.',
#   'could',
#   'was',
#   'said,',
#   'has',
#   'started',
#   'said,',
#   'had',
#   'said',
#   'has',
#   'has',
#   'failed,',
#   'was',
#   'was,',
#   'was',
#   'said',
#   'said—"Donald,',
#   'has',
#   'didn’t',
#   'wants',
#   'said',
#   'would',
#   'wasn’t',
#   'was',
#   'made',
#   'intelligent?"',
#   'won’t',
#   'used',
#   'wanted',
#   'can',
#   '—',
#   'worked',
#   'worked',
#   'wins,',
#   'always',
#   'ordered',
#   'was',
#   'said',
#   'ever',
#   'ever',
#   'ever',
#   '—',
#   'calls',
#   'doesn’t',
#   'used',
#   'used',
#   'was',
#   'decided',
#   'became',
#   'went',
#   'actually',
#   'is',
#   'spent',
#   'did?',
#   'takes',
#   'was',
#   '—',
#   'is',
#   'got.',
#   'doing',
#   'have',
#   'should',
#   'should',
#   'is',
#   'made',
#   'was',
#   'took',
#   'made',
#   'would',
#   'asked',
#   'asked',
#   'doesn’t',
#   'left,',
#   'said',
#   'can',
#   'went',
#   'beginning,',
#   'said,',
#   'is',
#   'is',
#   'said',
#   'is',
#   'means',
#   'said,',
#   'is',
#   'is',
#   'will',
#   'talks',
#   'has',
#   'speaks',
#   'is',
#   'said,',
#   'said,',
#   'said',
#   'said,',
#   'was',
#   'said,',
#   'said',
#   'was',
#   'said,',
#   'keeps',
#   'never',
#   'gets',
#   'goes',
#   'doesn’t',
#   'goes',
#   'was',
#   'was',
#   'loves',
#   'announced',
#   'is?',
#   'said',
#   'would',
#   'wanted',
#   'was',
#   'or',
#   'in',
#   'brought',
#   'stopped',
#   'was',
#   'was',
#   'traveled',
#   'traveled',
#   'constantly',
#   'wanted',
#   'was',
#   'deems',
#   'brought',
#   'is',
#   'was',
#   'travelled',
#   'travelled',
#   'agrees',
#   'agrees.',
#   'came',
#   'is',
#   'doing',
#   'gave',
#   'thinks',
#   'have',
#   'let',
#   'just',
#   'do',
#   'said',
#   'shouldn’t',
#   'likes',
#   'used',
#   'had',
#   'gets',
#   'win',
#   'wins',
#   'let',
#   'let',
#   'was',
#   'is',
#   'wasn’t',
#   'just',
#   'lost',
#   'lost.',
#   'lost.',
#   'said',
#   'said,',
#   'should',
#   'said',
#   'was',
#   'didn’t',
#   'got',
#   'just',
#   'showed',
#   'was',
#   'would',
#   'held',
#   'dealt',
#   'said,',
#   'said',
#   'can’t',
#   'comes',
#   'comes',
#   'was',
#   'doesn’t',
#   'should',
#   'looks',
#   'got',
#   'says.',
#   'is',
#   'likes',
#   'doesn’t',
#   'is',
#   'has',
#   'had',
#   'likes',
#   'likes',
#   'said,',
#   'is',
#   'liked',
#   'liked',
#   'really',
#   'takes',
#   'does',
#   'started',
#   'goes',
#   'lives',
#   'said,',
#   'said,',
#   'said,',
#   'comes',
#   'did',
#   'said',
#   'left',
#   'said,',
#   'does',
#   'says',
#   'comes',
#   'thought',
#   'was',
#   'lies',
#   'walks',
#   'walks',
#   'starts',
#   'is',
#   'doesn’t',
#   'was',
#   'asked',
#   'just',
#   'just',
#   'just',
#   'would',
#   'just',
#   'brought',
#   'wants.',
#   'got',
#   'wanted',
#   'wanted.',
#   'is',
#   'raises',
#   'starts',
#   'raises',
#   'would',
#   'said,',
#   'can',
#   'stands',
#   'lies.',
#   'said,',
#   'had',
#   'certainly',
#   'endorsed',
#   'comes',
#   'doesn’t',
#   'decided',
#   'was',
#   'was',
#   'was',
#   'came',
#   'gave',
#   'was',
#   'was',
#   'said,',
#   'was',
#   'endorse?',
#   'waits.',
#   'waits.',
#   'goes',
#   'stops',
#   'goes',
#   'shouldn’t',
#   'did.',
#   'left.',
#   'sent',
#   'do?',
#   'makes',
#   'have',
#   'told',
#   'started',
#   'wanted',
#   'gets',
#   'stands',
#   'filibusters,',
#   'was',
#   'comes',
#   'endorses',
#   'has',
#   'can’t',
#   'said',
#   'said',
#   'said',
#   'can',
#   'first',
#   'was',
#   'saw',
#   'didn’t',
#   'can’t',
#   'used',
#   'said',
#   'doesn’t',
#   'forgot',
#   'borrowed',
#   'hits',
#   'did',
#   'did',
#   'couldn’t',
#   'start',
#   'goes',
#   'touched',
#   'was',
#   'was',
#   'should',
#   'lost.',
#   'should',
#   'lost.',
#   'lost.',
#   'graduates',
#   'has',
#   'runs.',
#   'wins,',
#   'loses,',
#   'tells',
#   'goes,',
#   'was',
#   'does,',
#   'gets',
#   'can',
#   'doesn’t',
#   'does,',
#   'gets',
#   'will',
#   'doesn’t',
#   'wasn’t',
#   'should',
#   'was',
#   'was',
#   'was',
#   'could',
#   'was',
#   'was',
#   'finally',
#   'didn’t',
#   'goes,',
#   'was',
#   'wants',
#   'was',
#   'did',
#   'appoints',
#   'just',
#   'did',
#   'stole.',
#   'did',
#   'raises',
#   'tells',
#   'tells',
#   'does',
#   'does',
#   'going',
#   'taxes."',
#   'wanted',
#   'was',
#   'makes',
#   'does',
#   'can’t',
#   'came',
#   'had',
#   '[referring',
#   'started',
#   'insulted',
#   'did',
#   'insulted',
#   'did',
#   'wants',
#   'said',
#   'was',
#   'won’t',
#   'spends',
#   'spent',
#   'was',
#   'was',
#   'knows',
#   'said',
#   'was',
#   'said',
#   'was',
#   'says',
#   'said',
#   'said.',
#   'said',
#   'is',
#   'says',
#   'went',
#   'went',
#   'keeps',
#   'doesn’t',
#   'doesn’t.',
#   'always',
#   'left',
#   'was',
#   'left.',
#   'said,',
#   'lost',
#   'lost.',
#   'should',
#   'sort',
#   'lost.',
#   'became',
#   'came',
#   'said,',
#   'hits',
#   'really',
#   'really,',
#   'said',
#   'really',
#   'talked',
#   'has',
#   'hit',
#   'going',
#   'was',
#   'possibly',
#   'called',
#   'talks',
#   'won’t',
#   'announced."',
#   'wears',
#   'does,',
#   'won’t',
#   'doubled',
#   'didn’t',
#   'didn’t',
#   'wants.',
#   'went',
#   'says,',
#   'won',
#   'asked',
#   'was',
#   'deserted.',
#   'came',
#   'said',
#   'gave',
#   'was',
#   'would',
#   'wants',
#   'stays',
#   'has',
#   'hasn’t',
#   'doesn’t',
#   'should',
#   'can',
#   'is',
#   'did',
#   'was',
#   'has',
#   'certainly',
#   'did',
#   'gave',
#   'was',
#   'didn’t',
#   'lacks',
#   'would',
#   'says',
#   'wrote',
#   'carefully',
#   'was',
#   'saw',
#   'just',
#   'was',
#   'was',
#   'was',
#   'got',
#   'got',
#   'did',
#   'does.',
#   'wants',
#   'wants',
#   'wants',
#   'doesn’t',
#   'did',
#   'took',
#   'doing.',
#   'has',
#   'was',
#   'really',
#   'got',
#   'be',
#   'was',
#   'doing',
#   'really',
#   'say',
#   'said',
#   'said',
#   'was',
#   'was',
#   'said."',
#   'announces',
#   'has',
#   'comes',
#   'goes',
#   'looks',
#   'goes',
#   'can’t',
#   'gives',
#   'has',
#   'had',
#   'had',
#   'had',
#   'was',
#   'couldn’t',
#   'just',
#   'pays',
#   'think',
#   'is?"',
#   'writes',
#   'is.',
#   'said,',
#   'has',
#   'wants',
#   'said',
#   'wants',
#   'moved',
#   'moved',
#   'double-downed…',
#   'desperately',
#   'was',
#   'harder',
#   'said',
#   'will',
#   'may',
#   'said',
#   'won’t',
#   'won’t',
#   'wouldn’t',
#   'could',
#   'did',
#   'spends',
#   'probably',
#   'attacked',
#   'will',
#   'might',
#   'was',
#   'was',
#   'got',
#   'just',
#   'does',
#   'spends',
#   'may',
#   'knocks',
#   'loves',
#   'says',
#   'was',
#   'didn’t',
#   'said,',
#   'flipped',
#   'said',
#   'calls',
#   'goes',
#   'actually',
#   'could',
#   'could',
#   'can',
#   'make',
#   'wanted',
#   'said,',
#   'gave',
#   'is',
#   'signed',
#   'blamed',
#   'wanted',
#   'has',
#   'signs',
#   'has',
#   '–',
#   'was',
#   'wears',
#   'calmed',
#   'said,',
#   'goes',
#   'doubles',
#   'has',
#   'wasn’t',
#   'came',
#   'came',
#   'goes',
#   'said',
#   'goes',
#   'got',
#   'goes',
#   'make',
#   'said',
#   'make',
#   'could',
#   'was',
#   'fights',
#   'was',
#   'was',
#   'won',
#   'took',
#   'was',
#   'was',
#   'actually',
#   'did',
#   'got',
#   'builds',
#   'does,',
#   'builds',
#   'was',
#   'said',
#   'actually',
#   'looks',
#   'was',
#   'started,',
#   'was',
#   'took',
#   'agrees',
#   'talked',
#   'talked',
#   'went',
#   'endorse?',
#   'was'],
#  'a': ['great',
#   'fair',
#   'president',
#   'word',
#   'completely',
#   'conservative,',
#   'Republican.',
#   'disaster.',
#   'friend',
#   'doctor,',
#   'very',
#   'very',
#   '$5',
#   'lie.',
#   'filthy',
#   'big,',
#   'real,',
#   'fence.',
#   'beauty.',
#   'very,',
#   'big',
#   'person',
#   'deal.',
#   'border',
#   'president',
#   'long',
#   'declaratory',
#   'weak',
#   'different',
#   'speech',
#   'year',
#   'new',
#   'cutter;',
#   'cutter',
#   'lot',
#   'game',
#   'nuclear',
#   'little',
#   'cetain',
#   'position',
#   'situation',
#   'year',
#   'bridge',
#   'bridge',
#   'terraza',
#   'hole',
#   'white',
#   'lot',
#   'long',
#   'lot',
#   'problem',
#   'very',
#   'presidential',
#   'long',
#   'dealmaker',
#   'golfer',
#   'failed',
#   'much',
#   'disaster,',
#   'lot',
#   'big',
#   'shocking',
#   'few',
#   'teleprompter,',
#   'break.',
#   'man',
#   'woman',
#   'wonderful',
#   'certain',
#   'basic',
#   'great',
#   'new',
#   'timeless',
#   'look',
#   'lot',
#   'new',
#   'new',
#   'dangerous',
#   'western',
#   'result.',
#   'complete',
#   'huge',
#   'year.',
#   'serious',
#   'lot.',
#   'strong',
#   'free',
#   'president',
#   'disastrous',
#   'nuclear',
#   'nuclear',
#   'Trump',
#   'better',
#   'friendly',
#   'longstanding',
#   'few',
#   'force',
#   'friend',
#   'great',
#   'great,',
#   'very',
#   'long',
#   'better',
#   'clear',
#   'coherent',
#   'dictator',
#   'different',
#   'humanitarian',
#   'mess.',
#   'war',
#   'massive',
#   'video,',
#   'total',
#   'total',
#   'week',
#   'fact',
#   'great',
#   'friend',
#   'coherent',
#   'new',
#   'long-term',
#   'major',
#   'philosophical',
#   'dangerous',
#   'two-way',
#   'look',
#   'simple',
#   'nation',
#   'news',
#   '2017',
#   'nation,',
#   'foreign',
#   'horrible',
#   'total',
#   'position',
#   'deal',
#   'deal',
#   'massive',
#   'deficit',
#   'way',
#   'better',
#   'summit',
#   'separate',
#   'rebalancing',
#   'fresh',
#   'plan',
#   'capital',
#   'disciplined,',
#   'reckless,',
#   'complete',
#   'line',
#   'foreign',
#   'foreign',
#   'long',
#   'foreign',
#   'total',
#   'Trump',
#   'foreign',
#   'stem.',
#   'debate,',
#   'couple',
#   'correct',
#   'slightly',
#   'debate,',
#   'problem.',
#   'look',
#   'little',
#   'lie.',
#   'big',
#   'question',
#   'great',
#   'long',
#   'good',
#   'good',
#   'couple',
#   'lot',
#   'little',
#   'group',
#   'couple',
#   'great',
#   'lot',
#   'long',
#   'lot',
#   'lot',
#   'tremendous',
#   'trade',
#   'great',
#   'great',
#   'wonderful',
#   'trade',
#   'Chevrolet',
#   'dumping',
#   'hotel',
#   'hotel.',
#   'hotel,',
#   'bullet',
#   'sign',
#   'statistic',
#   'country',
#   'group',
#   'nation',
#   'disaster',
#   'tractor,',
#   'tractor,',
#   'disaster.TRUMP:',
#   'Web',
#   'religious',
#   'person’s',
#   'Christian',
#   'religious',
#   'pawn',
#   'Web',
#   'level',
#   'job.',
#   'job.',
#   'job."',
#   'very',
#   'friend',
#   'doctor,',
#   'disaster.',
#   'plan',
#   'good',
#   'politician,',
#   'chance.',
#   'leader',
#   'cheerleader.',
#   'great',
#   'great',
#   'great',
#   'leader.',
#   'cheerleader.',
#   'negative',
#   'negative',
#   'cheerleader;',
#   'wonderful',
#   'truly',
#   'really,',
#   'job.',
#   'country,',
#   'couple',
#   'number',
#   'clue.',
#   'clue.',
#   'bad',
#   'traitor.',
#   'no-good',
#   'look',
#   'disaster,',
#   'free',
#   'political',
#   'contribution',
#   'campaign,',
#   'couple',
#   'great',
#   'great',
#   'few',
#   'boat',
#   'minute,',
#   'big',
#   'big',
#   'war.',
#   'military',
#   'point',
#   'problem',
#   'bigger',
#   'terrible',
#   'company,',
#   'car',
#   'done',
#   'sudden,',
#   'few',
#   '$2.5',
#   'lot',
#   'nice',
#   '35-percent',
#   'good',
#   'call',
#   'little',
#   'little',
#   '—',
#   'military',
#   'call',
#   'day.',
#   'day.',
#   'billion',
#   'day.',
#   'fortune.',
#   'year',
#   'great',
#   'good',
#   'clue.',
#   'nice',
#   'nice',
#   'lot',
#   'very',
#   'third',
#   'lot',
#   'private',
#   'small',
#   'great',
#   'lot.',
#   'lot',
#   'lot',
#   'lot',
#   'large',
#   'statement,',
#   'financial',
#   'summary.',
#   'total',
#   'total',
#   'net',
#   'country',
#   'very,',
#   'woman',
#   'gun',
#   'disaster.',
#   'really',
#   'great',
#   'great',
#   'third',
#   'third',
#   'bubble.',
#   'stock',
#   'stock',
#   'bubble',
#   'very',
#   'tough',
#   'lot',
#   'lightweight,',
#   '20-point',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'great',
#   'place',
#   'place',
#   'company',
#   'clue',
#   'thing',
#   'plan',
#   'country',
#   'friend',
#   'little',
#   'lot',
#   'lot',
#   'job-producer.',
#   'lot',
#   'few',
#   'loser.',
#   'huge',
#   'tremendous',
#   'lot',
#   'unifier.',
#   'little',
#   'unifier.',
#   'big',
#   'very',
#   'shot',
#   'little',
#   'much',
#   'much',
#   'unified',
#   'much',
#   'much',
#   'look',
#   'much',
#   'much',
#   'lot',
#   'conservative,',
#   'common-sense',
#   'setup.',
#   'perfect',
#   'local',
#   'truth-teller',
#   'person',
#   'right',
#   'big',
#   'second.',
#   'movement."',
#   'crowd',
#   'small',
#   'movement;',
#   'lot',
#   'news',
#   'tweet',
#   'statement',
#   'good',
#   'bad',
#   'negotiation',
#   'great',
#   'deal',
#   'room',
#   'good',
#   'friend',
#   'lot',
#   'room',
#   'period',
#   'half',
#   'deal.',
#   'deal,',
#   'deal,',
#   'wall.',
#   'wall.',
#   'word',
#   'trade',
#   'year',
#   'businessman.',
#   'wall.',
#   'lot',
#   'serious',
#   'very',
#   'meeting',
#   'strong',
#   'big',
#   'big,',
#   'big,',
#   'look',
#   'look',
#   'look',
#   'disaster.',
#   'bigger',
#   'safe',
#   'little',
#   'week',
#   'lot',
#   'hail',
#   'bad',
#   'good',
#   'country',
#   'third',
#   'president.',
#   'clue.',
#   'look,',
#   'long',
#   'long',
#   'disaster.',
#   'criminal',
#   'sad',
#   'very,',
#   'country',
#   'country,',
#   'lot',
#   'great',
#   'little',
#   'party',
#   'democracy.',
#   'great',
#   'lot',
#   'lot',
#   'look',
#   'mile',
#   'very,',
#   'little',
#   'close',
#   'celebration.',
#   'celebration.',
#   'baby',
#   'special',
#   'unifier.',
#   'movement,',
#   'movement.',
#   'lot',
#   'record',
#   'record',
#   'signal.',
#   'little',
#   '—',
#   'penchant"',
#   'factor',
#   'poll',
#   'friend',
#   'while',
#   'low-energy',
#   'lot',
#   'lot.',
#   'commercial',
#   'great',
#   'couple',
#   'good',
#   'guy',
#   'lot',
#   'couple',
#   'statement,',
#   'statement',
#   'simple',
#   'question,',
#   'question,',
#   'disaster.',
#   'very',
#   'while,',
#   'nice',
#   'while,',
#   'statement',
#   'brutal',
#   'situation',
#   'terrible',
#   'mistake',
#   'typo,',
#   'mistake',
#   'strong',
#   'woman',
#   'headache.',
#   'big',
#   'speech',
#   'speech',
#   'couple',
#   'lot',
#   'school',
#   'local',
#   'lot',
#   'little',
#   'guy',
#   'black',
#   'nice',
#   'fan.',
#   '—',
#   'protester?',
#   'protester.',
#   'protester.',
#   'guy',
#   'lot',
#   'debate',
#   'couple',
#   'deal',
#   'thing',
#   'terrorist',
#   'lot',
#   'lot."',
#   'conspiracy',
#   'lot.',
#   'lot."',
#   'horrible',
#   'country',
#   'country.',
#   'country.',
#   'dumping',
#   'dumping',
#   'jeep,',
#   'military',
#   'year',
#   'half',
#   'lot',
#   'president',
#   'date.',
#   'time.',
#   'lot',
#   'couple',
#   'little',
#   'deal.',
#   'wall.',
#   'wall,',
#   'border.',
#   'legal',
#   'legal',
#   'very',
#   'problem',
#   'little',
#   'shower',
#   'very',
#   'believer',
#   'big',
#   'problem,',
#   'problem.',
#   'lot',
#   'problem.',
#   'problem.',
#   'lot',
#   'lot',
#   'lot',
#   'lot.',
#   'lot.',
#   'lot.',
#   'lot',
#   'hoax,',
#   'hoax.',
#   'money-making',
#   'hoax,',
#   'lot',
#   'great',
#   'great',
#   'great',
#   'year.',
#   'lot',
#   'lot',
#   'fortune.',
#   'Mercedes',
#   'billion',
#   'billion',
#   'day,',
#   'lot',
#   'lot',
#   'wall."',
#   'wall',
#   'wall."',
#   'lot',
#   'guy',
#   'great',
#   'big',
#   'website',
#   'call',
#   'wall.',
#   'very',
#   'nice',
#   'wall;',
#   'great',
#   'van',
#   'ramp.',
#   'picture',
#   'ramp',
#   'little',
#   'jeep',
#   'wall"',
#   'wall.',
#   'fortune',
#   'lot',
#   'trade',
#   'certain',
#   'mini-version',
#   'good',
#   'lot',
#   'wall.',
#   'wall.',
#   'toad',
#   'turtle',
#   'snake',
#   'friend',
#   'great',
#   'friend',
#   'big',
#   'look,',
#   'great',
#   'big',
#   'speaker.',
#   'doer.',
#   'clue.',
#   'much',
#   'nice',
#   'big',
#   'safe',
#   'safe',
#   'terrible',
#   'tremendous',
#   'fortune',
#   'massive',
#   'much',
#   'much',
#   'situation',
#   'dumping',
#   'journey,',
#   'journey',
#   'movement',
#   'movement.',
#   'noisy',
#   'noisy',
#   'call',
#   'couple',
#   'guy',
#   'great',
#   'very',
#   'television',
#   'waste',
#   'while;',
#   'story,',
#   'terrible',
#   'nice',
#   'wall',
#   'good',
#   'wall',
#   'wall.',
#   'wall.',
#   'wall.',
#   'lot',
#   'poll',
#   'couple',
#   'week',
#   'lot',
#   'guy',
#   'sudden,',
#   'Bernie',
#   'total',
#   'dose',
#   'tough',
#   'tough',
#   'tough',
#   'nice',
#   'sap.',
#   'break.',
#   'break.',
#   'break.',
#   'gun,',
#   'moron.',
#   'moron.',
#   'great',
#   'phenomenal',
#   'great',
#   'tough',
#   'strong-looking',
#   'gun',
#   'party',
#   'party.',
#   'party.',
#   'fiance',
#   'real',
#   'break.',
#   'tough',
#   'great',
#   'plant,',
#   'plant',
#   'good',
#   '$2.5',
#   'tax,',
#   'tax,',
#   'big',
#   'free',
#   'disaster.',
#   'part',
#   'look.',
#   'great',
#   'hell',
#   'job.',
#   'stock,',
#   'sense,',
#   'mandate.',
#   'special',
#   'little',
#   'place',
#   'very',
#   'big',
#   'great.',
#   'great',
#   'hospital',
#   'baby.',
#   'wonderful',
#   'few',
#   'number',
#   'couple',
#   'lot',
#   'really',
#   '$58',
#   'news',
#   'comment?',
#   'big',
#   'sudden',
#   'country',
#   'political',
#   'lot',
#   'much',
#   'plan',
#   'room',
#   'room',
#   'local',
#   'nation',
#   'number',
#   'number',
#   'great',
#   '9,000',
#   '10,000',
#   'movement."',
#   'young',
#   '5',
#   'long',
#   'dumping',
#   'ONE',
#   'lot',
#   'successful',
#   'good',
#   'successful',
#   'week',
#   'speech',
#   'later',
#   'disgrace.',
#   'moment',
#   'very',
#   'strike',
#   'nation.',
#   'regime',
#   'fact,',
#   'fact',
#   'dysfunctional',
#   'ban',
#   'nation',
#   'position',
#   'proven',
#   'full',
#   'full',
#   'responsible',
#   'place',
#   'national',
#   'quality',
#   'failed',
#   'free',
#   'few',
#   'slaughter,',
#   'presidential',
#   'new',
#   'new',
#   'Director',
#   'Secretary',
#   'war',
#   'year',
#   'right',
#   'look.',
#   'single',
#   'look',
#   'single',
#   'long',
#   'screening',
#   '500',
#   'better,',
#   'mainstream',
#   'choice',
#   'very,',
#   'term',
#   'result',
#   'friend',
#   'disgrace',
#   'privilege,',
#   'look',
#   'look',
#   'look',
#   'matter',
#   'partnership,',
#   'full',
#   'new',
#   'new',
#   'tolerant',
#   'safe',
#   'lifelong',
#   'newcomer',
#   'very',
#   'long',
#   'bad',
#   'certain',
#   'strategy',
#   'very',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'very,',
#   'contract',
#   'range',
#   'friend',
#   'friend',
#   'friend',
#   'friend',
#   'Security',
#   'total',
#   'deal.',
#   'table',
#   'deal',
#   'group',
#   'catastrophe',
#   'disaster',
#   'West',
#   'knife-wielding',
#   'solution.',
#   'resolution',
#   'facilitator',
#   'chance.',
#   'great',
#   'framework',
#   'second-class',
#   'society',
#   'society',
#   'tremendous',
#   'horrible,',
#   'barrier',
#   'culture',
#   'total',
#   'very',
#   'clear',
#   'daily',
#   'Jewish',
#   'Jewish',
#   'beautiful',
#   'truly',
#   'great',
#   'great',
#   'testament',
#   'testament',
#   'movement.',
#   'rigged',
#   'fighter.',
#   'long',
#   'politician',
#   'system',
#   'system',
#   'rigged',
#   'field',
#   'totally',
#   'President',
#   'corrupt',
#   'major',
#   'sad',
#   'disaster.',
#   'crowd,',
#   'crowd.',
#   'long',
#   'nation.',
#   'nation.',
#   'dominant',
#   'disgrace.',
#   'disaster,',
#   'disaster,',
#   'great',
#   'shame',
#   'speech',
#   'President,',
#   'later',
#   'disgrace.',
#   'moment',
#   'very',
#   'strike',
#   'nation.',
#   'country',
#   'regime',
#   'fact,',
#   'fact',
#   'dysfunctional',
#   'ban',
#   'nation',
#   'position',
#   'proven',
#   'full,',
#   'responsible',
#   'place',
#   'national',
#   'quality',
#   'failed',
#   'free',
#   'few',
#   'Presidential',
#   'Director',
#   'Secretary',
#   'year',
#   'right',
#   'single',
#   'screening',
#   '500%',
#   'better,',
#   'mainstream',
#   'mainstream',
#   'result',
#   'friend',
#   'privilege,',
#   'full',
#   'new',
#   'new',
#   'tolerant',
#   'safe',
#   'lot',
#   'great',
#   'few',
#   'wall.',
#   'total',
#   'lot',
#   'lot',
#   'lot',
#   'month',
#   'fantastic',
#   'fantastic',
#   'nice',
#   'long',
#   'lot',
#   'lot',
#   'big',
#   'big',
#   'great',
#   'lot.',
#   'little',
#   'tariff',
#   'different',
#   'good',
#   'good',
#   'great',
#   'great',
#   'great',
#   'record.',
#   'couple',
#   'big,',
#   'speech',
#   'speech,',
#   'crowd',
#   'confined',
#   'little',
#   'protester',
#   'button.',
#   'computer,',
#   'protester',
#   'fortune.',
#   'poll,',
#   'Des',
#   'great',
#   'small',
#   'negative',
#   'Christian.',
#   'Presbyterian.',
#   'Presbyterian.',
#   ...],
#  'great': ['guy.',
#   'respect',
#   'respect',
#   'buildings.',
#   'again.',
#   'potential.',
#   'hotels',
#   'again.',
#   'again.',
#   'honor.',
#   'president,',
#   'friend',
#   'power.',
#   'power',
#   'and',
#   'catastrophes,',
#   'catastrophes.',
#   'country',
#   'people',
#   '—',
#   '—',
#   'again.',
#   'hands,',
#   'place.',
#   'numbers',
#   'again,',
#   'again.',
#   'friend',
#   'friend',
#   'people.',
#   'friends.',
#   'evening.',
#   'state,',
#   'people.',
#   'again.',
#   'to',
#   'to',
#   '—',
#   'again.',
#   'cheerleader',
#   'spirit."',
#   'cheerleader.',
#   'again.',
#   'again.',
#   'again.',
#   'again.',
#   'again.',
#   'leadership,',
#   'manufacturer.',
#   'manufacturer,',
#   'product."',
#   'people.TRUMP:',
#   'victory.',
#   'again?',
#   'again.',
#   'negotiator.',
#   'deals',
#   'deals,',
#   'hotels.',
#   'financial',
#   'job.',
#   'again,',
#   'again.',
#   'again',
#   'to',
#   'to',
#   'win',
#   'a',
#   'respect',
#   'power.',
#   'deal,',
#   'deals,',
#   'businessman,',
#   'with',
#   'people.',
#   'with',
#   'with',
#   'with',
#   'support,',
#   'number',
#   'question,',
#   'and',
#   'people.',
#   'there.',
#   'business',
#   'guy.',
#   'deal',
#   'deal.',
#   'deal',
#   'job,',
#   'wall;',
#   'job',
#   'guy.',
#   'people.',
#   'businessman.',
#   'review.',
#   'speaker.',
#   'intellect,',
#   'phenomenons',
#   'people.',
#   'abusers',
#   'job',
#   'job.',
#   'job.',
#   'deal',
#   'again,',
#   'family',
#   'again.',
#   'military',
#   'business',
#   'equipment.',
#   'state.',
#   'people.',
#   'people',
#   'again,',
#   'again',
#   'respect',
#   'spirit.',
#   'trade',
#   'enthusiasm.',
#   'scorn',
#   'again.',
#   'land,',
#   'trade',
#   'again.',
#   'detail.',
#   'people',
#   'deal,',
#   'leadership',
#   'honor.',
#   'feeling.',
#   'feeling.',
#   'citizens.',
#   'trade',
#   'deal',
#   'for',
#   'potential',
#   'again,',
#   'scorn',
#   'job',
#   'with',
#   'again',
#   'state',
#   'family,',
#   'family',
#   'business.',
#   'poll',
#   'and',
#   'with',
#   'with',
#   'with',
#   'champions.',
#   'detail',
#   'groups.',
#   'again',
#   'business',
#   'marksmen.',
#   'shots',
#   'guy,',
#   'feeling.',
#   'feeling.',
#   'citizens.',
#   'trade',
#   'deal',
#   'for',
#   'potential',
#   'again!',
#   'period',
#   'party,',
#   'veterans’',
#   'organization',
#   'victories.',
#   'catastrophes',
#   'essentially.',
#   'it',
#   'applause',
#   'parents',
#   'again.',
#   'again.',
#   'to',
#   'president.',
#   'the',
#   'feeling.',
#   'relationships',
#   'trade',
#   'relationships',
#   'jobs',
#   'economic',
#   'thing',
#   'again.',
#   'again',
#   'singer',
#   'friend',
#   '–',
#   'friends,',
#   'job,',
#   'Trojan',
#   'Al',
#   'trade',
#   'trade',
#   'respect',
#   'Ford',
#   'company',
#   'companies,',
#   'guy,',
#   'company.',
#   'friends',
#   'friends',
#   'deal',
#   'negotiators.',
#   'budgets.',
#   'migration.',
#   'writers',
#   'health',
#   'people.',
#   'and',
#   'ones.',
#   'trade',
#   'evenings',
#   'country.',
#   'honor.',
#   'job?',
#   'job.',
#   'people.',
#   'company.',
#   'assets',
#   'in',
#   'in',
#   'in',
#   'poll.',
#   'numbers."',
#   'guy',
#   'farm',
#   'again.',
#   'guy.',
#   'Christians.',
#   'people',
#   'again."',
#   'again",',
#   'again"',
#   'with',
#   'company.',
#   'job',
#   'franchise.',
#   'quarterback.',
#   'quarterback.',
#   'quarterback.',
#   'quarterback',
#   'guy.',
#   'policy',
#   'service.',
#   'for',
#   'wife.',
#   'principals.',
#   '–',
#   'responsibility',
#   'is',
#   'company.',
#   'job',
#   'Adam',
#   'golfer.',
#   'Sarah',
#   'again.',
#   'evening.',
#   'guy,',
#   'people.',
#   'companies',
#   'company,',
#   'support.',
#   'conversation.',
#   'opportunity',
#   'anger.',
#   'anger.',
#   'deals.',
#   'victory.',
#   'again.',
#   'future.',
#   'future.',
#   'guy',
#   'champion.',
#   'champion',
#   'victories',
#   'Supreme',
#   'man',
#   'Second',
#   'again.',
#   'with',
#   'with.',
#   'people.',
#   'manufacturer.',
#   'shape.',
#   'with',
#   'trade',
#   'guy.',
#   'again.',
#   'again.',
#   'again.',
#   'again.',
#   'people.',
#   'job',
#   'success',
#   'and',
#   'achievement.',
#   'again.',
#   'company',
#   'assets,',
#   'place',
#   'with',
#   'again.',
#   '–',
#   'negotiators."',
#   'deal',
#   'if',
#   'with',
#   'with',
#   'with',
#   'things',
#   'respects',
#   'honor.',
#   'state',
#   'ship',
#   'one.',
#   'vets,',
#   'temperament.',
#   'again?',
#   'job',
#   'leaders',
#   'people.',
#   'day',
#   'negotiators.',
#   'negotiators.',
#   'hatred',
#   'harm',
#   'financial',
#   'company.',
#   'company',
#   'cash',
#   'piece',
#   'before',
#   'hotels',
#   'plan.',
#   'businessmen,',
#   'companies.',
#   'again.',
#   'husband,',
#   'friends',
#   'musicians',
#   'company',
#   'partner',
#   'secret',
#   'people.',
#   'feeling',
#   'again.',
#   'again…',
#   'hotel',
#   'if',
#   'thing',
#   'actually',
#   'dealmaker.',
#   'if',
#   'because',
#   'deal',
#   'catastrophes.',
#   'honor.',
#   'one.',
#   'job.',
#   'relationship,',
#   'relationship',
#   'relationship',
#   'relationship',
#   'personal',
#   'deals',
#   'relationships',
#   'cheerleader',
#   'divider',
#   'dividers',
#   'divider',
#   'question.',
#   'again.',
#   'developments',
#   'numbers.',
#   '–',
#   'business',
#   'properties',
#   'traders,',
#   'dealmakers.',
#   'companies',
#   'story',
#   'athlete.',
#   'things',
#   'people.',
#   'at',
#   'president."',
#   'victory',
#   'because',
#   'Christian',
#   'Christian.',
#   'victories',
#   'trade',
#   'scams',
#   'scams.',
#   'company.',
#   'company.',
#   'and',
#   'reporter.',
#   'reporter.',
#   'reporter.',
#   'with',
#   'with',
#   'poll',
#   'poll.',
#   'deals',
#   'military',
#   'team',
#   'stuff.',
#   'quality,',
#   'stuff.',
#   'deal',
#   'border',
#   'people.',
#   'question.',
#   'again.',
#   'company.',
#   'company.',
#   'economists',
#   'common',
#   'job.',
#   'honor.',
#   'place',
#   'ship',
#   'state.',
#   'guy',
#   'again.',
#   'again.',
#   'again.',
#   'honor.',
#   'again',
#   'again.',
#   'again.',
#   'company.',
#   'company.',
#   'respect.',
#   'talent',
#   'talent',
#   'talent',
#   'immigration',
#   'guy.',
#   'athlete.',
#   'builder',
#   'credit',
#   'businessman.',
#   'crowd,',
#   'again,',
#   'that',
#   'again.',
#   'with',
#   'with',
#   'with',
#   'relationships.',
#   'deals.',
#   'to',
#   'again.',
#   'again',
#   'people',
#   'buildings',
#   'successes.',
#   '–',
#   'people.',
#   'weather',
#   'weather.',
#   'people.',
#   'for',
#   'deals',
#   'reporter',
#   'school.',
#   'success.',
#   'guy',
#   'guy.',
#   'again.',
#   'because',
#   'relationship',
#   'guy,',
#   'experience.',
#   'schools,',
#   'brain,',
#   'success,',
#   'company,',
#   'Bill',
#   'success,',
#   'deal.',
#   'deal',
#   'manufacturer.',
#   'company',
#   'assets.',
#   'guy',
#   'guy.',
#   'money.',
#   'builder.',
#   'border',
#   'people.',
#   'with',
#   'and',
#   'if',
#   'businessman',
#   'success."',
#   'achievement.',
#   'achievement.',
#   'plans.',
#   'care',
#   'businessman',
#   'credit',
#   'credit.',
#   'time',
#   'answer.',
#   'strength',
#   'again.',
#   'again.',
#   'people,',
#   'leaders',
#   'gentleman',
#   'builder.',
#   'thing.',
#   'thing.',
#   'thing?',
#   'job,',
#   'job,',
#   'to',
#   'American',
#   'trade',
#   'Hillary'],
#  'guy.': ['He',
#   'He',
#   'But',
#   'Phil',
#   'But',
#   'But',
#   'They’re',
#   'He',
#   'But',
#   'But',
#   'I’m',
#   'This',
#   'I',
#   'But',
#   'I',
#   'Stay',
#   'Honestly,',
#   'So,',
#   'And',
#   'Dr.',
#   'But',
#   'Ben',
#   'What',
#   'He',
#   'And',
#   'Corey',
#   'He',
#   'And',
#   'Great',
#   'Wonderful',
#   'I',
#   'Young',
#   'You',
#   'But',
#   'We',
#   'I',
#   'A',
#   'Probably',
#   'One',
#   'What',
#   'So',
#   'Rich',
#   'Bought',
#   'They',
#   'For',
#   'This',
#   'One',
#   'Right?',
#   'Great',
#   'Really',
#   'You',
#   'I',
#   'He',
#   'And'],
#  'He': ["doesn't",
#   'said,',
#   'lied',
#   'never',
#   'did',
#   'got',
#   'does',
#   'failed.',
#   'had',
#   'choked.',
#   'is',
#   'negotiated',
#   'supported',
#   'has',
#   'should',
#   'has',
#   'said,',
#   'wanted',
#   'said,',
#   'loves',
#   'has',
#   'doesn’t',
#   'might',
#   'was',
#   'was',
#   'wasn’t',
#   'makes',
#   'said,',
#   'said,',
#   'said,',
#   'couldn’t',
#   'didn’t',
#   'was',
#   'didn’t',
#   'couldn’t',
#   'was',
#   'worked',
#   'had',
#   'spent',
#   'is',
#   'didn’t',
#   'hasn’t',
#   'hasn’t',
#   'called',
#   'said,',
#   'decided',
#   'had',
#   'didn’t',
#   'hasn’t',
#   'hasn’t',
#   'spent',
#   'is',
#   'spent',
#   'was',
#   'came',
#   'takes',
#   'shouldn’t',
#   'took',
#   'said,',
#   'should',
#   'gave',
#   'gives',
#   'talks',
#   'actually',
#   'said',
#   'looked',
#   'said,',
#   'said',
#   'goes,',
#   'said,',
#   'said,',
#   'didn’t',
#   'hasn’t',
#   'just',
#   'went',
#   'handle',
#   'was',
#   'would',
#   'gave',
#   'may',
#   'has',
#   'gave',
#   'was',
#   'came',
#   'calls',
#   'laughed.',
#   'said,',
#   'didn’t',
#   'said',
#   'said,',
#   'actually',
#   'said',
#   'is.',
#   'sets',
#   'said,',
#   'didn’t',
#   'knew',
#   'did',
#   'gave',
#   'talks',
#   'talks',
#   'talks',
#   'knows',
#   'said,',
#   'looks',
#   'let',
#   'was',
#   'is',
#   'just',
#   'is',
#   'is',
#   'wouldn’t',
#   'says,',
#   'says,',
#   'debates...I',
#   'doesn’t',
#   'came',
#   'wanted',
#   'said,',
#   'didn’t',
#   'thought',
#   'wanted',
#   'said,',
#   'loves',
#   'wants',
#   'said,',
#   'refused',
#   'gets',
#   'got',
#   'left.',
#   'said,',
#   'stands',
#   'says,',
#   'voted',
#   'came',
#   'handed',
#   'was',
#   'was',
#   'gave',
#   'sent',
#   'sends',
#   'started',
#   'goes',
#   'dislikes',
#   'calls',
#   'can',
#   'called',
#   'was',
#   'said',
#   'borrowed',
#   'forgot',
#   'just',
#   'said,',
#   'arrested',
#   'took',
#   'said,',
#   'was',
#   'goes',
#   'said,',
#   'writes',
#   'was',
#   'lived',
#   'wasn’t',
#   'is',
#   'lived',
#   'said,',
#   'said',
#   'will',
#   'said,',
#   'buys',
#   'just',
#   'said,',
#   'wanted',
#   'said',
#   'can’t',
#   'mentions',
#   'did',
#   'signed',
#   'loves',
#   'wants',
#   'looks',
#   'didn’t',
#   'refuses',
#   'refuses',
#   'was',
#   'gets',
#   'just',
#   'doesn’t',
#   'left.',
#   'deserted.',
#   'got',
#   'becomes',
#   'hated',
#   'knew',
#   'knew',
# ...
#   'in',
#   'back.',
#   'Lyin’',
#   'in',
#   'a',
#   '11',
#   'and',
#   'in',
#   'plenty',
#   'he',
#   'and',
#   'and',
#   'because',
#   'to',
#   'for',
#   'that',
#   'now',
#   'know',
#   'money.',
#   'anymore.',
#   'the',
#   'to',
#   'to',
#   'to',
#   '"You',
#   'the',
#   'up',
#   'up',
#   'by',
#   'pretty',
#   'back',
#   'as',
#   'the',
#   'at',
#   'all',
#   'again.',
#   'that',
#   'in',
#   'because',
#   'and',
#   'back.',
#   'back.',
#   'right',
#   'even',
#   'the',
#   'because',
#   'thrown',
#   'out',
#   'total',
#   'to',
#   'and',
#   'have',
#   'a',
#   'a',
#   'so',
#   'think',
#   'anyways."',
#   'out;',
#   'out',
#   'the',
#   'a',
#   'a',
#   'do',
#   'not',
#   'this',
#   'again',
#   'because',
#   'a',
#   'use',
#   'get',
#   'down.',
#   'down.',
#   'and',
#   'something',
#   'come',
#   'I',
#   'in',
#   'name.',
#   'a',
#   'right',
#   'the',
#   'as'],
#  'last': ['month.',
#   'thing',
#   'thing--',
#   'thing',
#   'couple',
#   'three',
#   'time',
#   'time',
#   'time',
#   'moment,',
#   'year,',
#   'couple',
#   '—',
#   'week',
#   'night',
#   'person',
#   'night,',
#   'thing',
#   'person',
#   'week',
#   'year',
#   'two',
#   'thing',
#   'person',
#   'major',
#   'five',
#   'week,',
#   'thing',
#   'person',
#   'major',
#   'moment.',
#   'week,',
#   'week.',
#   'couple',
#   'time',
#   'month',
#   'thing',
#   'three',
#   'year',
#   'week',
#   'one.',
#   'score',
#   'week,',
#   'time.',
#   'week',
#   'six',
#   'to',
#   'night',
#   'number',
#   'night',
#   'thing',
#   'year',
#   'deal.',
#   'short',
#   'week,',
#   'for',
#   'week',
#   'night',
#   'night',
#   'month',
#   'night.',
#   'a',
#   'night',
#   'debate',
#   'cycle,',
#   'debate?',
#   'year.',
#   'month.',
#   'week',
#   'time',
#   'week',
#   'cycle,',
#   'long',
#   '–',
#   'five',
#   'week',
#   '6,',
#   'poll.',
#   'poll,',
#   'night.',
#   'night.',
#   'two',
#   'two',
#   'poll',
#   'week,',
#   'season',
#   'box',
#   'night',
#   'night,',
#   'night.',
#   'night',
#   'night',
#   'meeting',
#   'week.',
#   'night',
#   'night,',
#   '20'],
#  'month.': ['He', 'I', 'And'],
#  'won.': ['And',
#   'I',
#   'You’ve',
#   'No,',
#   'And',
#   'We',
#   'The',
#   'Now,',
#   'And',
#   'We’ve',
#   'And',
#   'Remember?'],
#  'election,': ['sort', 'in', 'it', 'he', 'one', 'and'],
#  'dealmaker': ['that', '–', 'give'],
#  'guys;': ['they'],
#  'one-yard': ['line,'],
#  'line,': ['they', 'and', 'NBC', 'which'],
#  'ah,': ['ah'],
#  'ah': ['I'],
#  'Or': ['a',
#   'there’s',
#   'in',
#   'how',
#   'we',
#   'stupid.',
#   'they’re',
#   'a',
#   'are',
#   'whatever.',
#   'whatever.'],
#  'golfer': ['that'],
#  'sink': ['the', 'that'],
#  'three-footer': ['to'],
#  'win': ['the',
#   'than',
#   '—',
#   'our',
#   'if',
#   'this',
#   'too',
#   'six',
#   'because',
#   'in',
#   'anything.',
#   'very',
#   'most',
#   'them',
#   'anything.',
#   'something.',
#   'five',
#   'nine',
#   'all',
#   'everything.',
#   'anymore.',
#   'anymore.',
#   'a',
#   'a',
#   'so',
#   'a',
#   'a',
#   'so',
#   '—',
#   'it',
#   'by,',
#   "it's",
#   'anymore.',
#   'with',
#   'on',
#   'Iowa.',
#   'Iowa',
#   'Iowa,',
#   'Iowa,',
#   'virtually',
#   'the',
#   'Iowa,',
#   'everything',
#   'it’s',
#   'in',
#   'I',
#   'because',
#   'Iowa,',
#   'Iowa,',
#   'like',
#   'because',
#   '37',
#   'the',
#   'the',
#   'the',
#   'the',
#   'as',
#   'New',
#   'in',
#   'in',
#   'again.',
#   'big',
#   'all',
#   'in',
#   'big',
#   'anymore.',
#   'anymore.',
#   'with',
#   'with',
#   'anymore.',
#   'with',
#   'anymore.',
#   'anymore.',
#   'with',
#   'with',
#   'it;',
#   'it.',
#   'on',
#   'with',
#   'with',
#   'for',
#   'at',
#   'with',
#   'with',
#   'at',
#   'as',
#   'Wisconsin,',
#   'that',
#   'and',
#   'fast',
#   'that.',
#   'Wisconsin',
#   'Wisconsin,',
#   'because',
#   'a',
#   '–',
#   'anymore.',
#   'anymore.',
#   'anymore.',
#   'with',
#   'at',
#   'at',
#   'at',
#   'the',
#   'by',
#   'by',
#   'the',
#   'for',
#   'in',
#   'again.',
#   'very',
#   'anymore.',
#   'anymore.',
#   'again.',
#   'again.',
#   'so',
#   'so',
#   'Iowa,',
#   'anything.',
#   'anything.',
#   'the',
#   'the',
#   'the',
#   'and',
#   'because',
#   'anymore.',
#   'at',
#   'Iowa.',
#   'New',
#   'South',
#   'Iowa,',
#   'Iowa',
#   'it.',
#   'and',
#   'is',
#   'the',
#   'at',
#   'at',
#   'the',
#   'anymore.',
#   'anymore.',
#   'here.',
#   'on',
#   'militarily',
#   'on',
#   'on',
#   'on',
#   'for',
#   'New',
#   'Pennsylvania,',
#   'all',
#   'big'],
#  'tournament.': ['And', 'He’s'],
#  'Most': ['people',
#   'people',
#   'of',
#   'importantly,',
#   'of',
#   'people',
#   'incredible.',
#   'recently,',
#   'of',
#   'of',
#   'of',
#   'everybody.'],
#  'that;': ['I', "he's", 'reducing'],
#  'chance,': ["'cause"],
#  "'cause": ['actually'],
#  'tougher': ['to', 'people', 'than', 'than', 'deal.', 'in', 'than'],
#  'beating': ['a',
#   'Obama',
#   'the',
#   'the',
#   'us',
#   'Hillary',
#   'Hillary',
#   'Hillary',
#   'us',
#   'everybody',
#   '–',
#   'Hillary',
#   'us',
#   'you'],
#  'failed': ['president.',
#   'to',
#   'intervention',
#   'policies',
#   'to',
#   'immigration',
#   'us',
#   'us',
#   'immigration',
#   'us,',
#   'us',
#   'president.',
#   'president,',
#   'to',
#   'establishment',
#   'trade'],
#  'Obama': ['would',
#   'has',
#   'gutted',
#   'has',
#   'landed',
#   'watches',
#   'won’t',
#   'has',
#   'and',
#   'and',
#   'is',
#   'was',
#   'a',
#   'administration.',
#   'for',
#   'does',
#   'administration,',
#   'is',
#   'must',
#   'in',
#   'gets',
#   'have',
#   'thinks',
#   'change,',
#   'promised',
#   'disaster.',
#   'Administration,',
#   'must',
#   'or',
#   'didn’t',
#   'administration',
#   'change,',
#   'promised',
#   'disaster.',
#   'just',
#   'used',
#   'yesterday',
#   'yesterday',
#   'just',
#   'left',
#   'did',
#   'everything.',
#   'wants',
#   'pushing',
#   'now',
#   'got',
#   'administration.',
#   'is',
#   'would',
#   'during',
#   'administration.',
#   'administration?',
#   'is',
#   'definitely',
#   'and',
#   'was',
#   'said',
#   'has',
#   'got',
#   'has',
#   'told',
#   'administration',
#   'a',
#   'announces',
#   'signed',
#   'signed,',
#   'and',
#   'talks',
#   'always',
#   'comes',
#   'administration,',
#   'never',
#   'down',
#   'administration.',
#   'said,',
#   'administration,',
#   'predicted'],
#  'easier': ['one', 'to', 'to', 'just', 'actually', 'if', 'to', 'for'],
#  'up,': ['which',
#   'and',
#   'and',
#   'Steve.',
#   'because,',
#   'the',
#   'makes',
#   'nobody',
#   'right?',
#   '"We’d',
#   'we',
#   'silly',
#   'you',
#   'you',
#   'just',
#   'these',
#   '"Are',
#   'it',
#   'I',
#   'Bernie',
#   'they',
#   'immigration',
#   'nobody'],
#  'sad': ['to',
#   'day',
#   'position',
#   'and',
#   'day',
#   'to',
#   'day',
#   'to',
#   'but',
#   'circumstance',
#   'circumstance.',
#   'case.'],
#  'true.': ['So',
#   'This',
#   'On',
#   'You’re',
#   'He',
#   'He',
#   'And',
#   'First',
#   'I',
#   'And',
#   'It’s',
#   'It’s',
#   'No,',
#   'Not',
#   'He',
#   'And',
#   'I',
#   'Some',
#   'It’s',
#   'Do',
#   'It’s',
#   'So',
#   'Why',
#   'Elton',
#   'Some',
#   'You',
#   '$350,000.',
#   'Think',
#   'And',
#   'I',
#   'I',
#   'They’re',
#   'I',
#   'She',
#   'Well,',
#   'But',
#   'Remember',
#   'It’s',
#   'So',
#   '…Now,',
#   'Nothing',
#   'I’m',
#   'It’s',
#   'And',
#   'It’s',
#   'I',
#   'But',
#   'Japan'],
#  'Romney.': ['He', 'I', 'Mitt', 'Just', 'I', 'I', 'That', 'I'],
#  'Bush.': ['The',
#   'Now',
#   'Now,',
#   'And',
#   'He',
#   'So,',
#   'They',
#   'What’s',
#   'I',
#   'It’s',
#   'I',
#   'They’re'],
#  'need': ['is',
#   'is',
#   'to',
#   'to',
#   'a',
#   'a',
#   'of',
#   'to',
#   'to',
#   'to',
#   'be,',
#   'to',
#   'the',
#   'it',
#   'somebody,',
#   'the',
#   'a',
#   'a',
#   'somebody',
#   '—',
#   'somebody',
#   'somebody',
#   'to',
#   'people',
#   'really',
#   'anybody’s',
#   'anybody’s',
#   'for',
#   'money.',
#   'money.',
#   'the',
#   'anything.',
#   'it.',
#   'that',
#   '1,000',
#   '1,000',
#   'low-energy.',
#   'lots',
#   'for',
#   'to',
#   '1,000',
#   'strength,',
#   'toughness,',
#   'smarts.',
#   'it.',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'this',
#   'a',
#   'a',
#   'to',
#   'an',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'two',
#   'to',
#   'to',
#   'is',
#   'it.',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'an',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'is',
#   'government',
#   'a',
#   'to',
#   'the',
#   'the',
#   'borders',
#   'great',
#   'the',
#   'smart',
#   'in',
#   'some',
#   'somebody',
#   'Trump.',
#   'Trump.',
#   'Trump',
#   'the',
#   'to',
#   'to',
#   'eminent',
#   'a',
#   'protection',
#   'the',
#   'now',
#   'that',
#   'that',
#   'a',
#   'strength.',
#   'strength',
#   'a',
#   'somebody',
#   'somebody',
#   'tough.',
#   'smart.',
#   'like',
#   'in',
#   'to',
#   'them.',
#   'in',
#   '–',
#   'strength.',
#   'real',
#   'tough.',
#   'General',
#   'General',
#   'the',
#   'that.',
#   'Patton.',
#   'a',
#   'tremendous',
#   'a',
#   'a',
#   'somebody',
#   'somebody',
#   'somebody',
#   'pomp',
#   'some',
#   'spirit.',
#   'a',
#   'this',
#   'people',
#   'it.',
#   'it',
#   'your',
#   'to',
#   'help.',
#   '$1',
#   'to',
#   'smart',
#   'money',
#   'victories',
#   '–',
#   'in',
#   'money.',
#   'it',
#   'law',
#   'law',
#   'law',
#   'our',
#   'a',
#   'somebody',
#   '–',
#   'your',
#   'new',
#   'new',
#   'strength.',
#   'in',
#   'to',
#   'to',
#   'bilateral',
#   'to'],
#  'says': ['the',
#   'this',
#   'Trump',
#   'she',
#   'the',
#   'the',
#   'it’s',
#   'what’s',
#   'is',
#   'great,',
#   'that.',
#   'he’s',
#   'though',
#   'he’ll',
#   'that',
#   'the',
#   'she',
#   'all',
#   'it',
#   'is',
#   '–',
#   'it.',
#   'Trump,',
#   '"Oh,',
#   '"If',
#   'right',
#   'you',
#   'I',
#   'it',
#   'such',
#   'bleh".',
#   '"$50',
#   '"$50',
#   'it',
#   '–',
#   'I’m',
#   'don’t'],
#  'thing--': ['You'],
#  'copied': ['it.'],
#  'accused': ['of'],
#  'copying': ['the'],
#  'statement;': ["that's"],
#  'bad': ['thing.',
#   'as',
#   'the',
#   'dudes.',
#   'dudes',
#   'negotiator.',
#   'ones.',
#   'news.',
#   'for',
#   'news.',
#   'thing?',
#   'and',
#   'negotiation.',
#   'night,',
#   'that',
#   'an',
#   'that',
#   'for',
#   'guys.',
#   'trade',
#   'things',
#   'guys',
#   'deal.',
#   'Iran’s',
#   'as',
#   'a',
#   'guys',
#   '–',
#   'decisions.',
#   'guys',
#   'guys.',
#   'ones',
#   'is',
#   'as',
#   'things',
#   'for',
#   'as',
#   'publicity',
#   'part',
#   'there',
#   '–',
#   'and',
#   'judge.',
#   'witness',
#   'deals.',
#   'deals,',
#   'jobs.',
#   'jobs.',
#   'jobs."',
#   'deal.',
#   'automatically.',
#   'person',
#   'if',
#   'fight.',
#   'things',
#   'and',
#   'talker.',
#   'it',
#   'names.',
#   'names.',
#   'job',
#   'is',
#   'service,',
#   '–',
#   'people.',
#   'accident.',
#   'state.',
#   'people.',
#   'news',
#   'decisions...or',
#   'accident.',
#   'points',
#   'dudes.',
#   'people',
#   'guy,',
#   'things',
#   'guys',
#   'people.',
#   'news,',
#   'and',
#   'things',
#   'thing',
#   'record',
#   'things',
#   'things',
#   'for',
#   'intentions',
#   'things',
#   'for',
#   'for',
#   'things',
#   'guys',
#   'guys',
#   'guys,',
#   'thing',
#   'thing?',
#   'story,',
#   'ones.',
#   'gang',
#   'apples.',
#   'apples.',
#   'ones',
#   'dudes',
#   '–',
#   'ones',
#   'thing?',
#   'either.',
#   'things',
#   'shape',
#   'trade',
#   'about',
#   'about',
#   'deficits?',
#   'because',
#   'in',
#   'apples.',
#   'ones,'],
#  'first,': ['and', 'folks.', 'they', 'I'],
#  'totally': ['in',
#   'in',
#   'succeed',
#   'over',
#   'out',
#   'predictable.',
#   'against',
#   'welcome.',
#   'destabilize',
#   'wise',
#   'against',
#   'in',
#   'controlled',
#   'wrong.',
#   'disavow.',
#   'kill',
#   'destabilized',
#   'changed',
#   'changed',
#   'changed',
#   'one',
#   'distort',
#   'devastated,',
#   'incompetent',
#   'deadly.',
#   'dismantle',
#   'accountable.',
#   'unbreakable.',
#   'rigged',
#   'illegal',
#   'protecting',
#   'mistreated',
#   'devastated.',
#   'corrupt.',
#   'against',
#   'in',
#   'for',
#   'rigged',
#   'illegal',
#   'protecting',
#   'mistreated',
#   'accountable',
#   'involved',
#   'controlled',
#   'controlled',
#   'controlled',
#   'dishonest,',
#   'depleted.',
#   'under',
#   'but',
#   'phony.',
#   'phony',
#   'destabilize',
#   'self-funding',
#   'radicalized.',
#   'dishonest',
#   'radicalized.',
#   'control',
#   'controlled',
#   'agree',
#   'unique.',
#   'protected',
#   'protected.',
#   'destabilized',
#   'blew',
#   'insulting.',
#   'out',
#   'in',
#   'pledging',
#   'bought',
#   'owned',
#   'dishonest',
#   'for',
#   'against,'],
#  'favor': ['of',
#   'of',
#   'of',
#   'of',
#   'on',
#   'of',
#   'of',
#   'of',
#   'and',
#   'of',
#   'of',
#   'of',
#   'and'],
#  'Common': ['Core;',
#   'Core.',
#   'sense',
#   'Core.',
#   'Core',
#   'Core.',
#   'Core.',
#   'Core.',
#   'Core',
#   'core,',
#   'core',
#   'Core',
#   'Core.',
#   'Core.',
#   'Core.',
#   'Core,',
#   'Core.',
#   'Core.',
#   'Core.',
#   'Core',
#   'Core,',
#   'Core',
#   'Core.',
#   'Core'],
#  'Core;': ["that's"],
#  'disaster,': ["that's", 'and', 'a', 'for', 'by', 'which'],
#  'bad,': ['it',
#   'I',
#   'actually.',
#   'but',
#   'they’re',
#   'bad',
#   'evil',
#   'all',
#   'down,'],
#  'should': ['be',
#   'not',
#   'have',
#   'always',
#   'work',
#   'work',
#   'seek',
#   'understand',
#   'do',
#   'have',
#   'be',
#   '—',
#   'be',
#   'be',
#   'be',
#   'be',
#   'never',
#   'go',
#   'go',
#   'be',
#   'have',
#   'they',
#   'have',
#   'do',
#   'have',
#   'feel',
#   'have',
#   'they',
#   'be',
#   'admit',
#   'not',
#   'be',
#   'be',
#   'admit',
#   'not',
#   'stay',
#   'look',
#   'be',
#   'have',
#   'have',
#   'have."',
#   'have',
#   'have',
#   'have',
#   'be',
#   'be',
#   'be',
#   'be',
#   'you',
#   'have',
#   'have',
#   'I',
#   'I',
#   'have',
#   'be',
#   'be',
#   'have',
#   'have.',
#   'be',
#   'have',
#   'have',
#   'just',
#   'have',
#   'get',
#   'not',
#   'come',
#   'be',
#   'have',
#   'have',
#   'have.',
#   'use',
#   'now',
#   'have',
#   'have',
#   'come',
#   'have',
#   'have',
#   'have',
#   'come',
#   'pour',
#   'use',
#   'be',
#   'be',
#   'give',
#   'demonstrate.',
#   'not',
#   'get',
#   'get',
#   'get',
#   'be',
#   'the',
#   'have',
#   'be.',
#   'bring',
#   'they',
#   'be',
#   'talk',
#   'be',
#   'really',
#   'and',
#   'have',
#   'get',
#   'do',
#   'get.',
#   'come',
#   'be.',
#   'do',
#   'be',
#   'not',
#   'be',
#   'because',
#   'ask',
#   'I',
#   'ask',
#   'consider.',
#   'I',
#   'vote',
#   'get',
#   'have',
#   'be'],
#  'local': ['and',
#   'level',
#   'parents',
#   'level.',
#   'level.',
#   'and',
#   'and',
#   'areas.',
#   'doctors',
#   'hospitals.'],
#  'Core.': ["He's",
#   'Common',
#   'I',
#   'How',
#   'Common',
#   'We’re',
#   'We’re',
#   'You’re',
#   'We’re',
#   'We’re',
#   'We’re',
#   'When'],
#  "He's": ['very,', 'tough.', 'very', 'really', 'better'],
#  'immigration.': ["Don't",
#   'He’s',
#   'You',
#   'Is',
#   'The',
#   'Remember,',
#   'Took',
#   'Now,',
#   'And',
#   'You',
#   'It’s',
#   'Well,',
#   'But',
#   'And',
#   'Now,',
#   'And',
#   'I',
#   'They'],
#  'forget--remember': ['his'],
#  'statement--they': ['come'],
#  'love.': ['I', 'And', 'These', 'I', 'And', 'But', 'And', "That's"],
#  'what?': ['Come',
#   'We',
#   'it',
#   'No',
#   'I',
#   'We’re',
#   'The',
#   'Ford',
#   'They',
#   'We',
#   'If',
#   'In',
#   'When',
#   'Because',
#   'When',
#   'Why',
#   'If',
#   'I',
#   'I’m',
#   'If',
#   'It’s',
#   'We',
#   'Hopefully,',
#   'Look,',
#   'When',
#   'That’s',
#   'I',
#   'I’m',
#   'It’s',
#   'You',
#   'I',
#   'I’ll',
#   'We’re',
#   'People',
#   'They',
#   'If',
#   'I’m',
#   'It',
#   'People',
#   'We’re',
#   'It’s',
#   'I',
#   'They’re',
#   'I’ll',
#   'That’s',
#   'We',
#   'They'],
#  'Come': ['for', 'on.', 'on.', 'over', 'on.', 'on.', 'in.'],
#  'love?': ["You've", "They're", 'I’m'],
#  "You've": ['got'],
#  'coming,': ['half'],
#  'half': ['of',
#   'hour',
#   'ago.',
#   'of',
#   'refuses',
#   'of',
#   'and',
#   'weeks."',
#   'and',
#   'ago.',
#   'years',
#   'a',
#   'and',
#   'of',
#   'of'],
#  'criminals.': ["They're"],
#  'reasons,': ['and'],
#  'runs,': ['you', 'he'],
#  'remember': ['his',
#   'that',
#   'when',
#   'that.',
#   'the',
#   'Obama',
#   'this.',
#   '(ph)',
#   'this;',
#   'when',
#   'that,',
#   'this',
#   '--',
#   'that',
#   'that.',
#   'this:',
#   'it,',
#   'it.',
#   'this;',
#   'this:',
#   'this',
#   'this:',
#   'that.',
#   'this.',
#   'in',
#   'this.',
#   'the',
#   'when',
#   'that.',
#   'that.',
#   'that.',
#   'that.',
#   'what',
#   'this.',
#   'what',
#   'this,',
#   'when',
#   'what',
#   'this.',
#   'I',
#   'this,',
#   'this,',
#   'this',
#   'that',
#   'he',
#   'the',
#   'when',
#   'for',
#   'who',
#   'that.',
#   'the',
#   'that',
#   'a'],
#  'brother': ['really', 'gave', 'looking', 'was'],
#  'gave': ['us',
#   'us',
#   'ISIS',
#   'him',
#   'me',
#   'him',
#   'her',
#   'a',
#   'them',
#   'a',
#   'a',
#   'them',
#   'them',
#   'them',
#   'Iran',
#   'them,',
#   'them',
#   'them',
#   'the',
#   'them.',
#   'money',
#   'the',
#   'some',
#   '$1',
#   'it',
#   '$350,000',
#   'tremendous',
#   'money',
#   '$1',
#   'a',
#   '$500,000.',
#   '$1',
#   '$1',
#   'this',
#   '$5,600,000.',
#   'it',
#   '100%.',
#   'me',
#   'me',
#   'her',
#   '$50,000',
#   'him',
#   'me',
#   'you',
#   'a',
#   'up',
#   'him',
#   'it',
#   'Obama',
#   'us',
#   'to',
#   'them',
#   'up',
#   'up',
#   'them,',
#   'them',
#   'them',
#   'it',
#   'her',
#   'them',
#   'them',
#   'millions',
#   'to',
#   'them',
#   'him',
#   '$350,000',
#   'up',
#   'a',
#   'up',
#   'that',
#   'John',
#   'me',
#   'you,',
#   'me',
#   'me',
#   'up.',
#   'me',
#   'a',
#   'them'],
#  'Obama.': ['I', "'Cause", 'Do', 'Now,', 'They’re', 'I', 'I', 'I', 'He'],
#  'fan,': ['but'],
#  'Abraham': ['Lincoln', 'Lincoln,'],
#  'Lincoln': ['coming'],
#  ...}

# %%
while first_word.islower():
    first_word = np.random.choice(corpus)

# %%
first_word
# Out:
# 'I'

# %%
chain = [first_word]

# %%
n_words = 25

# %%
for i in range(n_words):
    chain.append(np.random.choice(word_dict[chain[-1]]))
' '.join(chain)
# Out:
# 'I do what feel?" He said was a reporter from the Art of the battleships, we raised the other day delays, and going to have three debates. They talked about the whole different groups, it because many people; I’ll tell you. Ask yourself, "How does not give them failed. I think so. They said, "You know the right here with their children. The father even say something, cause some very, very much, much worse and you have to attack everything. We are good people. We’ve got women. This is entitled to do this age but you’re predictable, you’re losing our country. The silent majority because I think he did with me. You’re here through with Mexico, it’s a friend of the border. We’re going to win; they’re made the FEC in this man just good president has allowed to happen. And we see that would be filing it so much for a great wall; it’s just killing us down. Our ambassador was worse and negotiate, it And we unleashed. Civil war, religious leader. That’s what they’re talking about it. It\'s a lot of days ago because I’m called me they took office. Total. Nothing in the world. The Apprentice? Who is coming in charge that change. But we told you know, at this country is that? I will work with the greatest defender and the wounded warriors all the end and stop people I was up and we’re not getting stronger because you want to rebuild our country. We’re going to happen. And we send stuff that Bernie Sanders — you mention her under the way, they’re going in a chapter. I mean anything. It’s time'
