# %%
import numpy as np

# %%
import csv

def write_csv(y_pred, filename):
    """Write a 1d numpy array to a Kaggle-compatible .csv file"""
    with open(filename, 'w') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Id', 'Category'])
        for idx, y in enumerate(y_pred):
            csv_writer.writerow([idx, y])


data = np.load('data_real.npz')
X_tst = data['x_tst']
y_pred = np.random.randint(0, 3, size=len(X_tst)) # random predictions
write_csv(y_pred, 'sample_predictions.csv')

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Proof

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Proof

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Proof

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### Proof

# %%
stuff = np.load("data_synth.npz")
X_trn = stuff['X_trn']
Y_trn = stuff['Y_train']
X_val = stuff['X_val']
Y_val = stuff['Y_val']

# %%
from scipy.special import comb
def get_poly_expansion(P):
    def expand(X):
        tmp = [np.sqrt(comb(P,p))*X**p for p in range(P+1)]
        return np.vstack(tmp).T
    return expand

# %% [markdown]
# ### Question 5

# %%
def eval_basis_expanded_ridge(x,w,h):
    expansion = h(x)
    y = np.dot(w,expansion.T)
    return y

# %% [markdown]
# ### Question 6

# %%
def train_basis_expanded_ridge(X,Y,λ,h = get_poly_expansion(3)):
    H = h(X)
    C = np.matmul(H.T,H) + λ*np.identity(H.shape[1])
    w = np.linalg.solve(C,np.matmul(H.T,Y))
    return w

# %%
train_basis_expanded_ridge(X_trn,Y_trn,0.1,h = get_poly_expansion(3))
# Out:
# array([ 2.2585207 , -0.4731082 ,  0.09166343, -0.0074039 ])

# %% [markdown]
# ### Question 7

# %%
P = [1,2,3,5,10]
λ = 0.1 
for p in P:
    h = get_poly_expansion(p)
    w = train_basis_expanded_ridge(X_trn,Y_trn,λ,h)
    print("Weight vector = " + str(w) + " for P = " + str(p) + "\n")
# Out:
# Weight vector = [1.00565302 0.12351259] for P = 1
#
# Weight vector = [ 1.55636445 -0.09905134  0.02105954] for P = 2
#
# Weight vector = [ 2.2585207  -0.4731082   0.09166343 -0.0074039 ] for P = 3
#
# Weight vector = [ 2.32031734e-01  1.70733532e+00 -7.50673263e-01  1.66018570e-01
#  -2.11820885e-02  1.49990203e-03] for P = 5
#
# Weight vector = [ 1.00207181e+00  3.45945567e-01 -6.77619200e-02  4.03404420e-02
#  -2.40833190e-02  7.29381906e-03 -1.30553266e-03  1.48669952e-04
#  -1.05198850e-05  3.68789523e-07  2.88162562e-09] for P = 10

# %%
import matplotlib.pyplot as plt
P = [1,2,3,5,10]
λ = 0.1 
for p in P:
    h = get_poly_expansion(p)
    w = train_basis_expanded_ridge(X_trn,Y_trn,λ,h)
    x = np.linspace(0,15,1000,endpoint = True)
    fwx = eval_basis_expanded_ridge(x,w,h)
    plt.scatter(x,fwx,s=15,label = "Learned Function Output")
    plt.scatter(X_trn,Y_trn,s =15,label = "Training Data")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Question 8

# %%
def get_poly_kernel(P):
    def k(x,xp):
        kernel_value = (1 + np.inner(x, xp)) ** P
        return kernel_value
    return k

# %%
x  = 0.5
xp = 0.7
k  = get_poly_kernel(5)
print(k(x,xp))
# Out:
# 4.484033437500002

# %% [markdown]
# ### Question 9

# %%
x  = 0.5
xp = 0.7
k  = get_poly_kernel(5)
h  = get_poly_expansion(5)
out1 = k(x,xp)
out2 = np.inner(h(x),h(xp))
print("output 1", out1)
print("output 2", out2)
# Out:
# output 1 4.484033437500002
# output 2 [[4.48403344]]

# %% [markdown]
# ### Question 10

# %%
def train_kernel_ridge(X,Y,λ,k):
    # Initiate a Kernel matrix
    K = np.zeros((X.shape[0],X.shape[0]))
    # Fill values for kernel matrix using kernel function
    for i in range(X.shape[0]):
        for j in range(X.shape[0]):
            K[i][j] = k(X[i],X[j])
    # Get first part for np.linalg.solve
    kli = K+λ*np.identity(K.shape[0])
    # Compute alpha
    α   = np.linalg.solve(kli,Y)
    return α

# %% [markdown]
# ### Question 11

# %%
def eval_kernel_ridge(X_trn, x, α, k):
    # Evaluation of kernel ridge regression
    sum_all = 0
    for i in range(len(X_trn)):
        sum_all += α[i]*k(X_trn[i],x)
    y = sum_all
    return y

# %%
k = get_poly_kernel(5)
α = train_kernel_ridge(X_trn,Y_trn,0.1,k = get_poly_kernel(9))

# %%
min(α)
# Out:
# -79.44190417923593

# %%
x = 5
eval_kernel_ridge(X_trn, 14, α, k)
min(α)
α
# Out:
# array([ 4.16175139e+01, -6.11504816e-02, -1.64004918e-01, -1.74916522e+00,
#         5.68538200e-02,  1.47495397e+00, -7.49248897e+00, -4.40246443e-02,
#         8.35771545e-02,  5.66312765e-01,  1.74852822e-01,  2.77420904e+00,
#        -1.91542350e+01,  4.90884270e+00, -2.08478049e+01,  1.47107320e+01,
#         5.00506841e+01,  6.35533214e-01, -1.15776572e+01,  6.74821030e+00,
#         2.12764866e+01, -1.25121343e-01, -4.72619681e-01, -2.14639233e+00,
#         2.28231210e-01,  1.24505610e-01, -1.05588739e+00,  8.04176447e-02,
#        -7.35611114e-02,  2.37470113e-02, -8.12527531e-01, -2.85545822e+00,
#        -1.85913769e+00, -2.01341606e+00,  2.37913566e-02,  2.03394969e-02,
#        -1.36167247e-02, -1.99499033e+00,  8.99363843e-01,  4.38467086e+00,
#        -2.27466118e+01,  1.73359756e-02,  2.09987972e+00, -6.63733091e-03,
#        -5.75871804e-03, -4.18117043e+01, -4.22488136e+00,  2.10654111e+00,
#         5.83226584e-01,  3.28436305e+01, -2.06937531e+00, -4.31154962e+00,
#        -1.21783001e+00,  2.04965481e+00, -2.43230997e+00, -2.36542868e+00,
#         3.17139564e-01,  1.33086741e+01, -5.89104483e-01,  1.10600562e-01,
#        -1.40278445e+00,  1.39510838e+01, -1.22472948e-01, -2.95774473e+00,
#        -7.94359187e-01, -1.46970391e+01, -5.56314848e-01,  6.99361370e-01,
    k = get_poly_kernel(p)
    α = train_kernel_ridge(X_trn,Y_trn,λ,k = get_poly_kernel(p))
    x = np.linspace(0,15,100)
    Y = []
    for i in range(len(x)):
        Y.append(eval_kernel_ridge(X_trn, x[i], α, k))
    Y = np.array(Y)
    plt.scatter(x,Y,s=15,label = "Learned Function Output")
    plt.scatter(X_trn,Y_trn,s =15,label = "Training Data")
    plt.legend()
    #plt.xlim([0, 10])
    plt.ylim([0, 20])
    plt.show()

# %% [markdown]
# ### Question 13

# %%
stuff=np.load("data_real.npz")
x_trn = stuff["x_trn"]
y_trn = stuff["y_trn"]
x_tst = stuff["x_tst"]

# %% [markdown]
# ### Question 14

# %%
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.metrics import hinge_loss

c = [2,20,200]

for penalty in c:
    hinge_losses = []

    kf = KFold(n_splits=5, shuffle=True, random_state=3815)
    for train_index, test_index in kf.split(x_trn):

        
        x_trn_5, x_tst_5 = x_trn[train_index], x_trn[test_index]
        y_trn_5, y_tst_5 = y_trn[train_index], y_trn[test_index]
    
    
        clf = svm.SVC(kernel = 'linear', C = 1/penalty)
        clf.fit(x_trn_5,y_trn_5)

        y_pred = clf.decision_function(x_tst_5)
        hinge_losses.append(hinge_loss(y_tst_5,y_pred))
        
          
        
    mean_hinge_loss = (sum(hinge_losses)/5)
    print("The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = " + str(penalty) + " is: ", mean_hinge_loss)
# Out:
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 is:  0.0392884618868216
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 is:  0.04736843051997232
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 is:  0.08278388214944607

# %% [markdown]
# ### Question 15

# %%
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.metrics import hinge_loss

c = [2,20,200]
gamma = [1,0.01,0.001]
for penalty in c:
      for g in gamma:

        hinge_losses = []

        kf = KFold(n_splits=5, shuffle=True, random_state=3815)
        for train_index, test_index in kf.split(x_trn):

            x_trn_5, x_tst_5 = x_trn[train_index], x_trn[test_index]
            y_trn_5, y_tst_5 = y_trn[train_index], y_trn[test_index]

            clf = svm.SVC(kernel = 'poly', degree = 3, C = 1/penalty, gamma = 1, coef0 = g)
            clf.fit(x_trn_5,y_trn_5)
            y_pred = clf.decision_function(x_tst_5)
            hinge_losses.append(hinge_loss(y_tst_5,y_pred))
        mean_hinge_loss = (sum(hinge_losses)/5)
        print("The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = " + str(penalty)  + " and gamma = " + str(g) + " is: " , mean_hinge_loss)
# Out:
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 1 is:  0.025151894662575315
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 0.01 is:  0.06848692866989378
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 0.001 is:  0.06295176096960745
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 1 is:  0.050936494127246545
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 0.01 is:  0.045395652953489705
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 0.001 is:  0.036529940801265745
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 1 is:  0.04624566308151824
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 0.01 is:  0.05459100420347988
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 0.001 is:  0.058211234060655606

# %% [markdown]
# ### Question 16

# %%
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.metrics import hinge_loss

c = [2,20,200]
gamma = [1,0.01,0.001]
for penalty in c:
      for g in gamma:

        hinge_losses = []

        kf = KFold(n_splits=5, shuffle=True, random_state=3815)
        for train_index, test_index in kf.split(x_trn):

            x_trn_5, x_tst_5 = x_trn[train_index], x_trn[test_index]
            y_trn_5, y_tst_5 = y_trn[train_index], y_trn[test_index]

            clf = svm.SVC(kernel = 'poly', degree = 5, C = 1/penalty, gamma = 1, coef0 = g)
            clf.fit(x_trn_5,y_trn_5)
            y_pred = clf.decision_function(x_tst_5)
            hinge_losses.append(hinge_loss(y_tst_5,y_pred))
        mean_hinge_loss = (sum(hinge_losses)/5)
        print("The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = " + str(penalty)  + " and gamma = " + str(g) + " is: " , mean_hinge_loss)
# Out:
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 1 is:  1.0178318686365588
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 0.01 is:  1.2408723555878485
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 0.001 is:  1.207107449574821
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 1 is:  1.0178318686365588
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 0.01 is:  1.0846464547722126
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 0.001 is:  0.9095336003374515
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 1 is:  2.653734304260972
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 0.01 is:  0.4404250663822936
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 0.001 is:  0.27887741541241

# %% [markdown]
# ### Question 17

# %%
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.metrics import hinge_loss

c = [2,20,200]
gamma = [1,0.01,0.001]
for penalty in c:
    for g in gamma:
        hinge_losses = []

        kf = KFold(n_splits=5, shuffle=True, random_state=3815)
        for train_index, test_index in kf.split(x_trn):

            x_trn_5, x_tst_5 = x_trn[train_index], x_trn[test_index]
            y_trn_5, y_tst_5 = y_trn[train_index], y_trn[test_index]

            clf = svm.SVC(kernel = 'rbf', C = 1/penalty, gamma = g)
            clf.fit(x_trn_5,y_trn_5)
            y_pred = clf.decision_function(x_tst_5)
            hinge_losses.append(hinge_loss(y_tst_5,y_pred))
        mean_hinge_loss = (sum(hinge_losses)/5)
        print("The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = " + str(penalty)  + " and gamma = " + str(g) + " is: " , mean_hinge_loss)
# Out:
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 1 is:  0.2476319942125214
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 0.01 is:  0.05688325763359631
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 2 and gamma = 0.001 is:  0.16053364409238383
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 1 is:  0.781123275538038
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 0.01 is:  0.2029859723498862
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 20 and gamma = 0.001 is:  0.6531256503139328
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 1 is:  0.8783744133306651
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 0.01 is:  0.7826658826112756
# The mean hinge loss with 5-Fold cross validation using hinge loss with lambda = 200 and gamma = 0.001 is:  0.8655626430253724

# %% [markdown]
# ### Question 18

# %%
clf_final = svm.SVC(kernel = 'rbf', C = 1/2, gamma = 0.01)
clf_final.fit(x_trn,y_trn)
y_pred = clf_final.predict(x_tst)
y_pred_li = np.array([int(i) for i in y_pred])
write_csv(y_pred_li,"question_18_final_check.csv")
